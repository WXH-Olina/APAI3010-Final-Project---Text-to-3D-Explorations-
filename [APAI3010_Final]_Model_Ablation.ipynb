# %% [markdown]
# # Install stable-dreamfusion
# - Manually set '-std=c++17' in all setup.py after downloading the repo!

# %%
# Assume that pwd is "/content"
# %%bash
git clone https://github.com/ashawkey/stable-dreamfusion.git
cd /content/stable-dreamfusion

pip install -r requirements.txt

# No need for this reproduction.
# cd /content/stable-dreamfusion/pretrained/zero123
# wget https://zero123.cs.columbia.edu/assets/zero123-xl.ckpt

# cd /content/stable-dreamfusion
# mkdir pretrained/omnidata
# cd pretrained/omnidata
# assume gdown is installed
# gdown '1Jrh-bRnJEjyMCS7f-WsaFlccfPjJPPHI&confirm=t' # omnidata_dpt_depth_v2.ckpt
# gdown '1wNxVO4vVbDEMEpnAi_jwQObf2MFodcBR&confirm=t' # omnidata_dpt_normal_v2.ckpt

# %% [markdown]
# # Training and testing

# %% [markdown]
# ## Ablation: R Precision for optimization options
# 1. Start from a simplified DreamFusion
# 2. Add a large range of viewpoints (ViewAug) -- Omitted
# 3. View-dependent prompts (ViewDep)
# 4. Illuminated renders (Lighting)
# 5. Textureless Shaded geometry images (Textureless)

# %%
## 1. Remove textureless rendering
# %cd /content/notebooks/stable-dreamfusion/nerf

import torch
from os import path
import random
from utils import *
from utils import Trainer

def train_step_without_textureless(self, data, save_guidance_path:Path=None):
    """
    Args:
    save_guidance_path: an image that combines the NeRF render, the added latent noise,
    the denoised result and optionally the fully-denoised image.
    """

    # perform RGBD loss instead of SDS if is image-conditioned
    do_rgbd_loss = self.opt.images is not None and \
        (self.global_step % self.opt.known_view_interval == 0)

    # override random camera with fixed known camera
    if do_rgbd_loss:
        data = self.default_view_data

    # experiment iterations ratio
    # i.e. what proportion of this experiment have we completed (in terms of iterations) so far?
    exp_iter_ratio = (self.global_step - self.opt.exp_start_iter) / (self.opt.exp_end_iter - self.opt.exp_start_iter)

    # progressively relaxing view range
    if self.opt.progressive_view:
        r = min(1.0, self.opt.progressive_view_init_ratio + 2.0*exp_iter_ratio)
        self.opt.phi_range = [self.opt.default_azimuth * (1 - r) + self.opt.full_phi_range[0] * r,
                              self.opt.default_azimuth * (1 - r) + self.opt.full_phi_range[1] * r]
        self.opt.theta_range = [self.opt.default_polar * (1 - r) + self.opt.full_theta_range[0] * r,
                                self.opt.default_polar * (1 - r) + self.opt.full_theta_range[1] * r]
        self.opt.radius_range = [self.opt.default_radius * (1 - r) + self.opt.full_radius_range[0] * r,
                                self.opt.default_radius * (1 - r) + self.opt.full_radius_range[1] * r]
        self.opt.fovy_range = [self.opt.default_fovy * (1 - r) + self.opt.full_fovy_range[0] * r,
                                self.opt.default_fovy * (1 - r) + self.opt.full_fovy_range[1] * r]

    # progressively increase max_level
    if self.opt.progressive_level:
        self.model.max_level = min(1.0, 0.25 + 2.0*exp_iter_ratio)

    rays_o = data['rays_o'] # [B, N, 3]
    rays_d = data['rays_d'] # [B, N, 3]
    mvp = data['mvp'] # [B, 4, 4]

    B, N = rays_o.shape[:2]
    H, W = data['H'], data['W']

    # When ref_data has B images > opt.batch_size
    if B > self.opt.batch_size:
        # choose batch_size images out of those B images
        choice = torch.randperm(B)[:self.opt.batch_size]
        B = self.opt.batch_size
        rays_o = rays_o[choice]
        rays_d = rays_d[choice]
        mvp = mvp[choice]

    if do_rgbd_loss:
        ambient_ratio = 1.0
        shading = 'lambertian' # use lambertian instead of albedo to get normal
        as_latent = False
        binarize = False
        bg_color = torch.rand((B * N, 3), device=rays_o.device)

        # add camera noise to avoid grid-like artifact
        if self.opt.known_view_noise_scale > 0:
            noise_scale = self.opt.known_view_noise_scale #* (1 - self.global_step / self.opt.iters)
            rays_o = rays_o + torch.randn(3, device=self.device) * noise_scale
            rays_d = rays_d + torch.randn(3, device=self.device) * noise_scale

    elif exp_iter_ratio <= self.opt.latent_iter_ratio:
        ambient_ratio = 1.0
        shading = 'normal'
        as_latent = True
        binarize = False
        bg_color = None

    else:
        if exp_iter_ratio <= self.opt.albedo_iter_ratio:
            ambient_ratio = 1.0
            shading = 'albedo'
        else:
            # random shading
            ambient_ratio = self.opt.min_ambient_ratio + (1.0-self.opt.min_ambient_ratio) * random.random()
            rand = random.random()
            if rand >= (1.0 - self.opt.textureless_ratio):
                shading = 'textureless'
                ##1st modification: removing textureless renders.##########################################################################################################
                shading = 'lambertian'
            else:
                shading = 'lambertian'

        as_latent = False

        # random weights binarization (like mobile-nerf) [NOT WORKING NOW]
        # binarize_thresh = min(0.5, -0.5 + self.global_step / self.opt.iters)
        # binarize = random.random() < binarize_thresh
        binarize = False

        # random background
        rand = random.random()
        if self.opt.bg_radius > 0 and rand > 0.5:
            bg_color = None # use bg_net
        else:
            bg_color = torch.rand(3).to(self.device) # single color random bg

    outputs = self.model.render(rays_o, rays_d, mvp, H, W, staged=False, perturb=True, bg_color=bg_color, ambient_ratio=ambient_ratio, shading=shading, binarize=binarize)
    pred_depth = outputs['depth'].reshape(B, 1, H, W)
    pred_mask = outputs['weights_sum'].reshape(B, 1, H, W)
    if 'normal_image' in outputs:
        pred_normal = outputs['normal_image'].reshape(B, H, W, 3)

    if as_latent:
        # abuse normal & mask as latent code for faster geometry initialization (ref: fantasia3D)
        pred_rgb = torch.cat([outputs['image'], outputs['weights_sum'].unsqueeze(-1)], dim=-1).reshape(B, H, W, 4).permute(0, 3, 1, 2).contiguous() # [B, 4, H, W]
    else:
        pred_rgb = outputs['image'].reshape(B, H, W, 3).permute(0, 3, 1, 2).contiguous() # [B, 3, H, W]

    # known view loss
    if do_rgbd_loss:
        gt_mask = self.mask # [B, H, W]
        gt_rgb = self.rgb   # [B, 3, H, W]
        gt_normal = self.normal # [B, H, W, 3]
        gt_depth = self.depth   # [B, H, W]

        if len(gt_rgb) > self.opt.batch_size:
            gt_mask = gt_mask[choice]
            gt_rgb = gt_rgb[choice]
            gt_normal = gt_normal[choice]
            gt_depth = gt_depth[choice]

        # color loss
        gt_rgb = gt_rgb * gt_mask[:, None].float() + bg_color.reshape(B, H, W, 3).permute(0,3,1,2).contiguous() * (1 - gt_mask[:, None].float())
        loss = self.opt.lambda_rgb * F.mse_loss(pred_rgb, gt_rgb)

        # mask loss
        loss = loss + self.opt.lambda_mask * F.mse_loss(pred_mask[:, 0], gt_mask.float())

        # normal loss
        if self.opt.lambda_normal > 0 and 'normal_image' in outputs:
            valid_gt_normal = 1 - 2 * gt_normal[gt_mask] # [B, 3]
            valid_pred_normal = 2 * pred_normal[gt_mask] - 1 # [B, 3]

            lambda_normal = self.opt.lambda_normal * min(1, self.global_step / self.opt.iters)
            loss = loss + lambda_normal * (1 - F.cosine_similarity(valid_pred_normal, valid_gt_normal).mean())

        # relative depth loss
        if self.opt.lambda_depth > 0:
            valid_gt_depth = gt_depth[gt_mask] # [B,]
            valid_pred_depth = pred_depth[:, 0][gt_mask] # [B,]
            lambda_depth = self.opt.lambda_depth * min(1, self.global_step / self.opt.iters)
            loss = loss + lambda_depth * (1 - self.pearson(valid_pred_depth, valid_gt_depth))

            # # scale-invariant
            # with torch.no_grad():
            #     A = torch.cat([valid_gt_depth, torch.ones_like(valid_gt_depth)], dim=-1) # [B, 2]
            #     X = torch.linalg.lstsq(A, valid_pred_depth).solution # [2, 1]
            #     valid_gt_depth = A @ X # [B, 1]
            # lambda_depth = self.opt.lambda_depth #* min(1, self.global_step / self.opt.iters)
            # loss = loss + lambda_depth * F.mse_loss(valid_pred_depth, valid_gt_depth)

    # novel view loss
    else:

        loss = 0

        if 'SD' in self.guidance:
            # interpolate text_z
            azimuth = data['azimuth'] # [-180, 180]

            # ENHANCE: remove loop to handle batch size > 1
            text_z = [self.embeddings['SD']['uncond']] * azimuth.shape[0]
            if self.opt.perpneg:

                text_z_comp, weights = adjust_text_embeddings(self.embeddings['SD'], azimuth, self.opt)
                text_z.append(text_z_comp)

            else:
                for b in range(azimuth.shape[0]):
                    if azimuth[b] >= -90 and azimuth[b] < 90:
                        if azimuth[b] >= 0:
                            r = 1 - azimuth[b] / 90
                        else:
                            r = 1 + azimuth[b] / 90
                        start_z = self.embeddings['SD']['front']
                        end_z = self.embeddings['SD']['side']
                    else:
                        if azimuth[b] >= 0:
                            r = 1 - (azimuth[b] - 90) / 90
                        else:
                            r = 1 + (azimuth[b] + 90) / 90
                        start_z = self.embeddings['SD']['side']
                        end_z = self.embeddings['SD']['back']
                    text_z.append(r * start_z + (1 - r) * end_z)

            text_z = torch.cat(text_z, dim=0)
            if self.opt.perpneg:
                loss = loss + self.guidance['SD'].train_step_perpneg(text_z, weights, pred_rgb, as_latent=as_latent, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance,
                                                save_guidance_path=save_guidance_path)
            else:
                loss = loss + self.guidance['SD'].train_step(text_z, pred_rgb, as_latent=as_latent, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance,
                                                                save_guidance_path=save_guidance_path)

        if 'IF' in self.guidance:
            # interpolate text_z
            azimuth = data['azimuth'] # [-180, 180]

            # ENHANCE: remove loop to handle batch size > 1
            text_z = [self.embeddings['IF']['uncond']] * azimuth.shape[0]
            if self.opt.perpneg:
                text_z_comp, weights = adjust_text_embeddings(self.embeddings['IF'], azimuth, self.opt)
                text_z.append(text_z_comp)
            else:
                for b in range(azimuth.shape[0]):
                    if azimuth[b] >= -90 and azimuth[b] < 90:
                        if azimuth[b] >= 0:
                            r = 1 - azimuth[b] / 90
                        else:
                            r = 1 + azimuth[b] / 90
                        start_z = self.embeddings['IF']['front']
                        end_z = self.embeddings['IF']['side']
                    else:
                        if azimuth[b] >= 0:
                            r = 1 - (azimuth[b] - 90) / 90
                        else:
                            r = 1 + (azimuth[b] + 90) / 90
                        start_z = self.embeddings['IF']['side']
                        end_z = self.embeddings['IF']['back']
                    text_z.append(r * start_z + (1 - r) * end_z)

            text_z = torch.cat(text_z, dim=0)

            if self.opt.perpneg:
                loss = loss + self.guidance['IF'].train_step_perpneg(text_z, weights, pred_rgb, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance)
            else:
                loss = loss + self.guidance['IF'].train_step(text_z, pred_rgb, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance)

        if 'zero123' in self.guidance:

            polar = data['polar']
            azimuth = data['azimuth']
            radius = data['radius']

            loss = loss + self.guidance['zero123'].train_step(self.embeddings['zero123']['default'], pred_rgb, polar, azimuth, radius, guidance_scale=self.opt.guidance_scale,
                                                              as_latent=as_latent, grad_scale=self.opt.lambda_guidance, save_guidance_path=save_guidance_path)

        if 'clip' in self.guidance:

            # empirical, far view should apply smaller CLIP loss
            lambda_guidance = 10 * (1 - abs(azimuth) / 180) * self.opt.lambda_guidance

            loss = loss + self.guidance['clip'].train_step(self.embeddings['clip'], pred_rgb, grad_scale=lambda_guidance)

    # regularizations
    if not self.opt.dmtet:

        if self.opt.lambda_opacity > 0:
            loss_opacity = (outputs['weights_sum'] ** 2).mean()
            loss = loss + self.opt.lambda_opacity * loss_opacity

        if self.opt.lambda_entropy > 0:
            alphas = outputs['weights'].clamp(1e-5, 1 - 1e-5)
            # alphas = alphas ** 2 # skewed entropy, favors 0 over 1
            loss_entropy = (- alphas * torch.log2(alphas) - (1 - alphas) * torch.log2(1 - alphas)).mean()
            lambda_entropy = self.opt.lambda_entropy * min(1, 2 * self.global_step / self.opt.iters)
            loss = loss + lambda_entropy * loss_entropy

        if self.opt.lambda_2d_normal_smooth > 0 and 'normal_image' in outputs:
            # pred_vals = outputs['normal_image'].reshape(B, H, W, 3).permute(0, 3, 1, 2).contiguous()
            # smoothed_vals = TF.gaussian_blur(pred_vals.detach(), kernel_size=9)
            # loss_smooth = F.mse_loss(pred_vals, smoothed_vals)
            # total-variation
            loss_smooth = (pred_normal[:, 1:, :, :] - pred_normal[:, :-1, :, :]).square().mean() + \
                          (pred_normal[:, :, 1:, :] - pred_normal[:, :, :-1, :]).square().mean()
            loss = loss + self.opt.lambda_2d_normal_smooth * loss_smooth

        if self.opt.lambda_orient > 0 and 'loss_orient' in outputs:
            loss_orient = outputs['loss_orient']
            loss = loss + self.opt.lambda_orient * loss_orient

        if self.opt.lambda_3d_normal_smooth > 0 and 'loss_normal_perturb' in outputs:
            loss_normal_perturb = outputs['loss_normal_perturb']
            loss = loss + self.opt.lambda_3d_normal_smooth * loss_normal_perturb

    else:

        if self.opt.lambda_mesh_normal > 0:
            loss = loss + self.opt.lambda_mesh_normal * outputs['normal_loss']

        if self.opt.lambda_mesh_laplacian > 0:
            loss = loss + self.opt.lambda_mesh_laplacian * outputs['lap_loss']

    return pred_rgb, pred_depth, loss


# Monkey patching
Trainer.train_step = train_step_without_textureless
# Out:
# /content/notebooks/stable-dreamfusion/nerf
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)

# %%
# %cd "/content/notebooks/stable-dreamfusion"
# !python main.py -O --text "A bulldog is wearing a black pirate hat." --workspace ablation_trial
# !python main.py --workspace ablation_trial -O --test
# Out:
# /content/notebooks/stable-dreamfusion
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='', O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# 2025-04-27 10:12:52.123443: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745748772.433834   30376 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745748772.521400   30376 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 10:12:53.169902: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] loading stable diffusion...
# model_index.json: 100% 543/543 [00:00<00:00, 3.93MB/s]
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/1.36G [00:00<?, ?B/s]
#
# config.json: 100% 613/613 [00:00<00:00, 4.26MB/s]
#
#
# scheduler_config.json: 100% 346/346 [00:00<00:00, 2.80MB/s]
#
#
# tokenizer_config.json: 100% 807/807 [00:00<00:00, 6.01MB/s]
#
#
# merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# preprocessor_config.json: 100% 342/342 [00:00<00:00, 2.80MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:02,  5.16it/s]
#
#
# special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.75MB/s]
#
# model.safetensors:   2% 21.0M/1.36G [00:00<00:08, 163MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.46G [00:00<?, ?B/s]
#
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
#
#
# vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
#
# config.json: 100% 911/911 [00:00<00:00, 6.09MB/s]
#
#
#
#
#
#
# config.json: 100% 553/553 [00:00<00:00, 2.33MB/s]
#
#
# merges.txt: 100% 525k/525k [00:00<00:00, 2.83MB/s]
#
# model.safetensors:   4% 52.4M/1.36G [00:00<00:05, 226MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   6% 21.0M/335M [00:00<00:02, 139MB/s]
#
#
#
#
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.28MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  13% 41.9M/335M [00:00<00:01, 163MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.46G [00:00<01:32, 37.5MB/s]
# model.safetensors:   6% 83.9M/1.36G [00:00<00:06, 191MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/3.46G [00:00<00:59, 58.0MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  19% 62.9M/335M [00:00<00:01, 144MB/s]
# model.safetensors:   8% 105M/1.36G [00:00<00:08, 150MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/3.46G [00:00<00:38, 89.2MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  25% 83.9M/335M [00:00<00:01, 142MB/s]
# model.safetensors:   9% 126M/1.36G [00:00<00:08, 149MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 52.4M/3.46G [00:00<00:36, 92.7MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  31% 105M/335M [00:00<00:01, 145MB/s]
# model.safetensors:  11% 147M/1.36G [00:00<00:07, 161MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 73.4M/3.46G [00:00<00:31, 108MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  38% 126M/335M [00:00<00:01, 126MB/s]
# model.safetensors:  12% 168M/1.36G [00:01<00:09, 126MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 94.4M/3.46G [00:01<00:34, 98.4MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  44% 147M/335M [00:01<00:01, 129MB/s]
# model.safetensors:  14% 189M/1.36G [00:01<00:08, 132MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 115M/3.46G [00:01<00:37, 89.8MB/s]
# model.safetensors:  15% 210M/1.36G [00:01<00:10, 115MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  50% 168M/335M [00:01<00:01, 103MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 126M/3.46G [00:01<00:39, 85.3MB/s]
# model.safetensors:  17% 231M/1.36G [00:01<00:09, 122MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  56% 189M/335M [00:02<00:03, 40.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 136M/3.46G [00:03<03:04, 18.1MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:03<00:05, 26.3MB/s]
# model.safetensors:  18% 252M/1.36G [00:03<00:40, 27.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 157M/3.46G [00:03<01:58, 27.9MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:03<00:03, 37.3MB/s]
# model.safetensors:  20% 273M/1.36G [00:03<00:29, 37.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 168M/3.46G [00:03<01:39, 33.2MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:03<00:02, 42.7MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:03<00:01, 48.4MB/s]
# model.safetensors:  22% 294M/1.36G [00:04<00:23, 45.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 189M/3.46G [00:03<01:10, 46.6MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:04<00:01, 63.8MB/s]
# model.safetensors:  23% 315M/1.36G [00:04<00:18, 57.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 210M/3.46G [00:04<00:54, 59.2MB/s]
# model.safetensors:  25% 336M/1.36G [00:04<00:14, 70.7MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:04<00:00, 78.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 231M/3.46G [00:04<00:43, 75.1MB/s]
# model.safetensors:  26% 357M/1.36G [00:04<00:11, 85.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 252M/3.46G [00:04<00:37, 86.4MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:04<00:00, 84.2MB/s]
# model.safetensors:  28% 377M/1.36G [00:04<00:09, 98.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:   8% 273M/3.46G [00:04<00:33, 95.1MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  97% 325M/335M [00:04<00:00, 85.2MB/s]
# model.safetensors:  29% 398M/1.36G [00:04<00:10, 93.0MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:04<00:00, 67.0MB/s]
#
# model.safetensors:  31% 419M/1.36G [00:05<00:10, 88.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 315M/3.46G [00:05<00:30, 103MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 336M/3.46G [00:05<00:30, 104MB/s]
# model.safetensors:  32% 440M/1.36G [00:05<00:10, 89.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 357M/3.46G [00:05<00:28, 108MB/s]
# model.safetensors:  34% 461M/1.36G [00:05<00:09, 92.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  11% 377M/3.46G [00:05<00:25, 120MB/s]
# model.safetensors:  35% 482M/1.36G [00:05<00:08, 106MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 398M/3.46G [00:05<00:24, 127MB/s]
# model.safetensors:  37% 503M/1.36G [00:06<00:10, 85.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.46G [00:06<00:31, 96.8MB/s]
# model.safetensors:  38% 514M/1.36G [00:06<00:10, 79.7MB/s]
# model.safetensors:  39% 524M/1.36G [00:06<00:10, 78.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 440M/3.46G [00:06<00:36, 84.0MB/s]
# model.safetensors:  39% 535M/1.36G [00:06<00:11, 74.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 451M/3.46G [00:06<00:39, 77.2MB/s]
# model.safetensors:  40% 545M/1.36G [00:06<00:12, 66.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 461M/3.46G [00:06<00:41, 71.7MB/s]
# model.safetensors:  41% 556M/1.36G [00:06<00:12, 66.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 472M/3.46G [00:06<00:41, 71.6MB/s]
# model.safetensors:  42% 566M/1.36G [00:07<00:11, 67.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 482M/3.46G [00:07<00:43, 69.2MB/s]
# model.safetensors:  42% 577M/1.36G [00:07<00:11, 67.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 493M/3.46G [00:07<00:42, 69.9MB/s]
# model.safetensors:  43% 587M/1.36G [00:07<00:11, 64.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 503M/3.46G [00:07<00:45, 65.8MB/s]
# model.safetensors:  44% 598M/1.36G [00:07<00:11, 66.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 514M/3.46G [00:07<00:44, 66.9MB/s]
# model.safetensors:  45% 608M/1.36G [00:07<00:11, 67.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 524M/3.46G [00:07<00:43, 67.5MB/s]
# model.safetensors:  45% 619M/1.36G [00:07<00:10, 73.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 545M/3.46G [00:07<00:32, 88.5MB/s]
# model.safetensors:  47% 640M/1.36G [00:07<00:07, 95.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 566M/3.46G [00:07<00:26, 108MB/s]
# model.safetensors:  49% 661M/1.36G [00:08<00:06, 110MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 587M/3.46G [00:08<00:24, 117MB/s]
# model.safetensors:  50% 682M/1.36G [00:08<00:05, 121MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 608M/3.46G [00:08<00:24, 117MB/s]
# model.safetensors:  52% 703M/1.36G [00:08<00:05, 123MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 629M/3.46G [00:08<00:23, 122MB/s]
# model.safetensors:  53% 724M/1.36G [00:08<00:04, 129MB/s]
# model.safetensors:  55% 744M/1.36G [00:08<00:04, 138MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 650M/3.46G [00:08<00:22, 126MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 671M/3.46G [00:08<00:22, 123MB/s]
# model.safetensors:  56% 765M/1.36G [00:08<00:04, 121MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 692M/3.46G [00:08<00:21, 131MB/s]
# model.safetensors:  58% 786M/1.36G [00:09<00:04, 121MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 713M/3.46G [00:09<00:21, 127MB/s]
# model.safetensors:  59% 807M/1.36G [00:09<00:04, 128MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 734M/3.46G [00:09<00:22, 124MB/s]
# model.safetensors:  61% 828M/1.36G [00:09<00:04, 126MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 755M/3.46G [00:09<00:21, 128MB/s]
# model.safetensors:  62% 849M/1.36G [00:09<00:04, 127MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 776M/3.46G [00:09<00:20, 130MB/s]
# model.safetensors:  64% 870M/1.36G [00:09<00:03, 128MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 797M/3.46G [00:09<00:19, 135MB/s]
# model.safetensors:  65% 891M/1.36G [00:09<00:03, 134MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 818M/3.46G [00:09<00:19, 137MB/s]
# model.safetensors:  67% 912M/1.36G [00:10<00:03, 134MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 839M/3.46G [00:09<00:17, 149MB/s]
#
#
# diffusion_pytorch_model.safetensors:  25% 870M/3.46G [00:10<00:14, 180MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 902M/3.46G [00:10<00:12, 209MB/s]
# model.safetensors:  69% 933M/1.36G [00:10<00:04, 103MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 933M/3.46G [00:10<00:11, 216MB/s]
# model.safetensors:  70% 954M/1.36G [00:10<00:03, 103MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 965M/3.46G [00:10<00:11, 217MB/s]
# model.safetensors:  72% 975M/1.36G [00:10<00:03, 104MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 996M/3.46G [00:10<00:15, 158MB/s]
# model.safetensors:  73% 996M/1.36G [00:10<00:03, 105MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 1.02G/3.46G [00:10<00:14, 166MB/s]
# model.safetensors:  75% 1.02G/1.36G [00:11<00:02, 120MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 1.05G/3.46G [00:11<00:13, 174MB/s]
# model.safetensors:  76% 1.04G/1.36G [00:11<00:02, 119MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 1.07G/3.46G [00:11<00:15, 157MB/s]
# model.safetensors:  78% 1.06G/1.36G [00:11<00:02, 115MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 1.09G/3.46G [00:11<00:16, 146MB/s]
# model.safetensors:  79% 1.08G/1.36G [00:11<00:02, 124MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.46G [00:11<00:16, 143MB/s]
# model.safetensors:  81% 1.10G/1.36G [00:11<00:02, 119MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 1.13G/3.46G [00:11<00:16, 140MB/s]
# model.safetensors:  82% 1.12G/1.36G [00:11<00:01, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 1.15G/3.46G [00:11<00:18, 124MB/s]
# model.safetensors:  84% 1.14G/1.36G [00:12<00:01, 121MB/s]
# model.safetensors:  85% 1.16G/1.36G [00:12<00:01, 132MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 1.17G/3.46G [00:12<00:19, 117MB/s]
# model.safetensors:  87% 1.18G/1.36G [00:12<00:01, 120MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 1.20G/3.46G [00:12<00:22, 99.9MB/s]
# model.safetensors:  89% 1.21G/1.36G [00:12<00:01, 110MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 1.22G/3.46G [00:12<00:20, 111MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 1.24G/3.46G [00:12<00:18, 121MB/s]
# model.safetensors:  90% 1.23G/1.36G [00:12<00:01, 109MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 1.26G/3.46G [00:12<00:18, 117MB/s]
# model.safetensors:  92% 1.25G/1.36G [00:13<00:01, 108MB/s]
#
#
# diffusion_pytorch_model.safetensors:  37% 1.28G/3.46G [00:13<00:24, 90.1MB/s]
# model.safetensors:  93% 1.27G/1.36G [00:13<00:01, 88.8MB/s]
# model.safetensors:  95% 1.29G/1.36G [00:13<00:00, 107MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.30G/3.46G [00:13<00:20, 105MB/s]
# model.safetensors:  96% 1.31G/1.36G [00:13<00:00, 125MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.32G/3.46G [00:13<00:18, 118MB/s]
# model.safetensors:  98% 1.33G/1.36G [00:13<00:00, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:  39% 1.34G/3.46G [00:14<00:53, 39.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  39% 1.36G/3.46G [00:15<00:41, 50.3MB/s]
# model.safetensors: 100% 1.36G/1.36G [00:15<00:00, 89.2MB/s]
# Fetching 13 files:  38% 5/13 [00:15<00:26,  3.27s/it]
#
#
# diffusion_pytorch_model.safetensors:  40% 1.39G/3.46G [00:16<01:00, 34.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  41% 1.42G/3.46G [00:16<00:47, 43.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  41% 1.44G/3.46G [00:16<00:36, 55.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  42% 1.47G/3.46G [00:16<00:25, 77.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  43% 1.50G/3.46G [00:16<00:18, 104MB/s]
#
#
# diffusion_pytorch_model.safetensors:  44% 1.53G/3.46G [00:16<00:14, 133MB/s]
#
#
# diffusion_pytorch_model.safetensors:  45% 1.56G/3.46G [00:17<00:15, 121MB/s]
#
#
# diffusion_pytorch_model.safetensors:  46% 1.59G/3.46G [00:17<00:12, 150MB/s]
#
#
# diffusion_pytorch_model.safetensors:  47% 1.64G/3.46G [00:17<00:09, 186MB/s]
#
#
# diffusion_pytorch_model.safetensors:  48% 1.67G/3.46G [00:17<00:08, 200MB/s]
#
#
# diffusion_pytorch_model.safetensors:  49% 1.70G/3.46G [00:17<00:08, 217MB/s]
#
#
# diffusion_pytorch_model.safetensors:  50% 1.74G/3.46G [00:17<00:07, 242MB/s]
#
#
# diffusion_pytorch_model.safetensors:  51% 1.77G/3.46G [00:18<00:06, 245MB/s]
#
#
# diffusion_pytorch_model.safetensors:  52% 1.80G/3.46G [00:18<00:06, 258MB/s]
#
#
# diffusion_pytorch_model.safetensors:  53% 1.84G/3.46G [00:18<00:06, 256MB/s]
#
#
# diffusion_pytorch_model.safetensors:  54% 1.87G/3.46G [00:18<00:06, 265MB/s]
#
#
# diffusion_pytorch_model.safetensors:  55% 1.90G/3.46G [00:18<00:05, 273MB/s]
#
#
# diffusion_pytorch_model.safetensors:  56% 1.93G/3.46G [00:18<00:05, 281MB/s]
#
#
# diffusion_pytorch_model.safetensors:  57% 1.97G/3.46G [00:18<00:05, 283MB/s]
#
#
# diffusion_pytorch_model.safetensors:  58% 2.00G/3.46G [00:18<00:05, 284MB/s]
#
#
# diffusion_pytorch_model.safetensors:  59% 2.03G/3.46G [00:18<00:05, 282MB/s]
#
#
# diffusion_pytorch_model.safetensors:  60% 2.07G/3.46G [00:19<00:04, 287MB/s]
#
#
# diffusion_pytorch_model.safetensors:  61% 2.11G/3.46G [00:19<00:04, 295MB/s]
#
#
# diffusion_pytorch_model.safetensors:  62% 2.14G/3.46G [00:19<00:04, 289MB/s]
#
#
# diffusion_pytorch_model.safetensors:  63% 2.17G/3.46G [00:19<00:04, 292MB/s]
#
#
# diffusion_pytorch_model.safetensors:  64% 2.20G/3.46G [00:19<00:04, 296MB/s]
#
#
# diffusion_pytorch_model.safetensors:  64% 2.23G/3.46G [00:19<00:04, 299MB/s]
#
#
# diffusion_pytorch_model.safetensors:  65% 2.26G/3.46G [00:19<00:04, 293MB/s]
#
#
# diffusion_pytorch_model.safetensors:  66% 2.30G/3.46G [00:19<00:03, 294MB/s]
#
#
# diffusion_pytorch_model.safetensors:  67% 2.33G/3.46G [00:19<00:03, 288MB/s]
#
#
# diffusion_pytorch_model.safetensors:  68% 2.36G/3.46G [00:20<00:04, 275MB/s]
#
#
# diffusion_pytorch_model.safetensors:  69% 2.39G/3.46G [00:20<00:04, 267MB/s]
#
#
# diffusion_pytorch_model.safetensors:  70% 2.42G/3.46G [00:20<00:03, 268MB/s]
#
#
# diffusion_pytorch_model.safetensors:  71% 2.45G/3.46G [00:20<00:03, 271MB/s]
#
#
# diffusion_pytorch_model.safetensors:  72% 2.49G/3.46G [00:20<00:03, 274MB/s]
#
#
# diffusion_pytorch_model.safetensors:  73% 2.52G/3.46G [00:20<00:03, 255MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.55G/3.46G [00:20<00:03, 247MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.58G/3.46G [00:20<00:03, 237MB/s]
#
#
# diffusion_pytorch_model.safetensors:  75% 2.61G/3.46G [00:21<00:03, 233MB/s]
#
#
# diffusion_pytorch_model.safetensors:  76% 2.64G/3.46G [00:21<00:03, 235MB/s]
#
#
# diffusion_pytorch_model.safetensors:  77% 2.67G/3.46G [00:21<00:03, 237MB/s]
#
#
# diffusion_pytorch_model.safetensors:  78% 2.71G/3.46G [00:21<00:03, 239MB/s]
#
#
# diffusion_pytorch_model.safetensors:  79% 2.74G/3.46G [00:21<00:02, 245MB/s]
#
#
# diffusion_pytorch_model.safetensors:  80% 2.77G/3.46G [00:21<00:02, 256MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.46G [00:21<00:02, 249MB/s]
#
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.46G [00:21<00:02, 254MB/s]
#
#
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.46G [00:22<00:02, 259MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.46G [00:22<00:02, 239MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 2.93G/3.46G [00:22<00:02, 233MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 2.96G/3.46G [00:22<00:02, 220MB/s]
#
#
# diffusion_pytorch_model.safetensors:  86% 2.99G/3.46G [00:22<00:02, 235MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 3.02G/3.46G [00:22<00:01, 244MB/s]
#
#
# diffusion_pytorch_model.safetensors:  88% 3.05G/3.46G [00:22<00:01, 241MB/s]
#
#
# diffusion_pytorch_model.safetensors:  89% 3.08G/3.46G [00:23<00:01, 238MB/s]
#
#
# diffusion_pytorch_model.safetensors:  90% 3.11G/3.46G [00:23<00:01, 242MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 3.15G/3.46G [00:23<00:01, 253MB/s]
#
#
# diffusion_pytorch_model.safetensors:  92% 3.19G/3.46G [00:23<00:01, 272MB/s]
#
#
# diffusion_pytorch_model.safetensors:  93% 3.22G/3.46G [00:23<00:00, 278MB/s]
#
#
# diffusion_pytorch_model.safetensors:  94% 3.25G/3.46G [00:23<00:00, 283MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 3.29G/3.46G [00:23<00:00, 296MB/s]
#
#
# diffusion_pytorch_model.safetensors:  96% 3.32G/3.46G [00:24<00:00, 199MB/s]
#
#
# diffusion_pytorch_model.safetensors:  97% 3.36G/3.46G [00:24<00:00, 212MB/s]
#
#
# diffusion_pytorch_model.safetensors:  98% 3.39G/3.46G [00:24<00:00, 192MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 3.42G/3.46G [00:24<00:00, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 3.46G/3.46G [00:24<00:00, 140MB/s]
# Fetching 13 files: 100% 13/13 [00:24<00:00,  1.92s/it]
# Loading pipeline components...: 100% 6/6 [00:26<00:00,  4.46s/it]
# [INFO] loaded stable diffusion!
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py -O --text A bulldog is wearing a black pirate hat. --workspace
# ablation_trial
# [INFO] opt: Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='',
# O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100,
# workspace='ablation_trial', seed=None, image=None, image_config=None, known_view_interval=4,
# IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256,
# decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False,
# perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001,
# ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32,
# update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0,
# min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2,
# jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1,
# bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2,
# backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64,
# known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1,
# dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180],
# fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20,
# progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30,
# angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001,
# lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5,
# lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0,
# lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_10-13-52 | cuda | fp16 | ablation_trial
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [WARN] No checkpoint found, model randomly initialized.
# ==> [2025-04-27_10-13-53] Start Training ablation_trial Epoch 1/100, lr=0.050000 ...
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1044: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=14183.3330 (14103.1061), lr=0.050000:  16% 16/100 [01:32<00:33,  2.49it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=42938.9570 (15563.4556), lr=0.050000: 100% 100/100 [01:55<00:00,  1.16s/it]
# ==> [2025-04-27_10-15-49] Finished Epoch 1/100. CPU=3.5GB, GPU=11.9GB.
# ++> Evaluate ablation_trial at epoch 1 ...
#   0% 0/8 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1141: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.15it/s]
# ++> Evaluate epoch 1 Finished.
# ==> [2025-04-27_10-15-56] Start Training ablation_trial Epoch 2/100, lr=0.050000 ...
# loss=19210.5000 (14672.8151), lr=0.050000: 100% 100/100 [00:28<00:00,  3.52it/s]
# ==> [2025-04-27_10-16-25] Finished Epoch 2/100. CPU=3.5GB, GPU=13.1GB.
# ++> Evaluate ablation_trial at epoch 2 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:08<00:00,  1.12s/it]
# ++> Evaluate epoch 2 Finished.
# ==> [2025-04-27_10-16-35] Start Training ablation_trial Epoch 3/100, lr=0.050000 ...
# loss=1939.8534 (14704.1566), lr=0.050000: 100% 100/100 [00:32<00:00,  3.06it/s]
# ==> [2025-04-27_10-17-07] Finished Epoch 3/100. CPU=3.5GB, GPU=8.2GB.
# ++> Evaluate ablation_trial at epoch 3 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:09<00:00,  1.17s/it]
# ++> Evaluate epoch 3 Finished.
# ==> [2025-04-27_10-17-18] Start Training ablation_trial Epoch 4/100, lr=0.050000 ...
# loss=29081.6523 (14674.8201), lr=0.050000: 100% 100/100 [00:31<00:00,  3.21it/s]
# ==> [2025-04-27_10-17-49] Finished Epoch 4/100. CPU=3.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 4 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:08<00:00,  1.02s/it]
# ++> Evaluate epoch 4 Finished.
# ==> [2025-04-27_10-17-58] Start Training ablation_trial Epoch 5/100, lr=0.050000 ...
# loss=22960.3242 (11279.6856), lr=0.050000: 100% 100/100 [00:29<00:00,  3.34it/s]
# ==> [2025-04-27_10-18-28] Finished Epoch 5/100. CPU=3.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 5 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:07<00:00,  1.08it/s]
# ++> Evaluate epoch 5 Finished.
# ==> [2025-04-27_10-18-37] Start Training ablation_trial Epoch 6/100, lr=0.050000 ...
# loss=811.1752 (14792.4581), lr=0.050000: 100% 100/100 [00:29<00:00,  3.41it/s]
# ==> [2025-04-27_10-19-06] Finished Epoch 6/100. CPU=3.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 6 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.29it/s]
# ++> Evaluate epoch 6 Finished.
# ==> [2025-04-27_10-19-14] Start Training ablation_trial Epoch 7/100, lr=0.050000 ...
# loss=6980.7227 (16016.0720), lr=0.050000: 100% 100/100 [00:27<00:00,  3.66it/s]
# ==> [2025-04-27_10-19-41] Finished Epoch 7/100. CPU=3.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 7 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.48it/s]
# ++> Evaluate epoch 7 Finished.
# ==> [2025-04-27_10-19-48] Start Training ablation_trial Epoch 8/100, lr=0.050000 ...
# loss=154.2506 (13773.8046), lr=0.050000: 100% 100/100 [00:27<00:00,  3.62it/s]
# ==> [2025-04-27_10-20-15] Finished Epoch 8/100. CPU=3.4GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 8 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.55it/s]
# ++> Evaluate epoch 8 Finished.
# ==> [2025-04-27_10-20-22] Start Training ablation_trial Epoch 9/100, lr=0.050000 ...
# loss=14367.5781 (15027.6009), lr=0.050000: 100% 100/100 [00:28<00:00,  3.55it/s]
# ==> [2025-04-27_10-20-50] Finished Epoch 9/100. CPU=2.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 9 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.59it/s]
# ++> Evaluate epoch 9 Finished.
# ==> [2025-04-27_10-20-56] Start Training ablation_trial Epoch 10/100, lr=0.050000 ...
# loss=20372.8633 (16903.9189), lr=0.050000: 100% 100/100 [00:25<00:00,  3.90it/s]
# ==> [2025-04-27_10-21-22] Finished Epoch 10/100. CPU=2.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 10 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.72it/s]
# ++> Evaluate epoch 10 Finished.
# ==> [2025-04-27_10-21-28] Start Training ablation_trial Epoch 11/100, lr=0.050000 ...
# loss=593.6639 (15632.1369), lr=0.050000: 100% 100/100 [00:25<00:00,  3.95it/s]
# ==> [2025-04-27_10-21-53] Finished Epoch 11/100. CPU=2.5GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 11 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.77it/s]
# ++> Evaluate epoch 11 Finished.
# ==> [2025-04-27_10-21-59] Start Training ablation_trial Epoch 12/100, lr=0.050000 ...
# loss=22364.7969 (16434.8410), lr=0.050000: 100% 100/100 [00:24<00:00,  4.01it/s]
# ==> [2025-04-27_10-22-24] Finished Epoch 12/100. CPU=2.4GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 12 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.77it/s]
# ++> Evaluate epoch 12 Finished.
# ==> [2025-04-27_10-22-29] Start Training ablation_trial Epoch 13/100, lr=0.050000 ...
# loss=3453.9216 (18542.1821), lr=0.050000: 100% 100/100 [00:24<00:00,  4.02it/s]
# ==> [2025-04-27_10-22-54] Finished Epoch 13/100. CPU=2.4GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 13 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.95it/s]
# ++> Evaluate epoch 13 Finished.
# ==> [2025-04-27_10-22-59] Start Training ablation_trial Epoch 14/100, lr=0.050000 ...
# loss=13848.1416 (16005.4316), lr=0.050000: 100% 100/100 [00:24<00:00,  4.07it/s]
# ==> [2025-04-27_10-23-24] Finished Epoch 14/100. CPU=2.4GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 14 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.01it/s]
# ++> Evaluate epoch 14 Finished.
# ==> [2025-04-27_10-23-29] Start Training ablation_trial Epoch 15/100, lr=0.050000 ...
# loss=28641.5957 (18564.1729), lr=0.050000: 100% 100/100 [00:24<00:00,  4.15it/s]
# ==> [2025-04-27_10-23-53] Finished Epoch 15/100. CPU=2.3GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 15 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.07it/s]
# ++> Evaluate epoch 15 Finished.
# ==> [2025-04-27_10-23-58] Start Training ablation_trial Epoch 16/100, lr=0.050000 ...
# loss=3748.4692 (15705.7284), lr=0.050000: 100% 100/100 [00:23<00:00,  4.22it/s]
# ==> [2025-04-27_10-24-22] Finished Epoch 16/100. CPU=2.3GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 16 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.04it/s]
# ++> Evaluate epoch 16 Finished.
# ==> [2025-04-27_10-24-27] Start Training ablation_trial Epoch 17/100, lr=0.050000 ...
# loss=11040.3809 (18155.1366), lr=0.050000: 100% 100/100 [00:23<00:00,  4.21it/s]
# ==> [2025-04-27_10-24-51] Finished Epoch 17/100. CPU=2.3GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 17 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.13it/s]
# ++> Evaluate epoch 17 Finished.
# ==> [2025-04-27_10-24-56] Start Training ablation_trial Epoch 18/100, lr=0.050000 ...
# loss=21905.7188 (18148.0758), lr=0.050000: 100% 100/100 [00:23<00:00,  4.23it/s]
# ==> [2025-04-27_10-25-20] Finished Epoch 18/100. CPU=2.3GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 18 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.14it/s]
# ++> Evaluate epoch 18 Finished.
# ==> [2025-04-27_10-25-25] Start Training ablation_trial Epoch 19/100, lr=0.050000 ...
# loss=26842.9863 (19132.0048), lr=0.050000: 100% 100/100 [00:23<00:00,  4.22it/s]
# ==> [2025-04-27_10-25-48] Finished Epoch 19/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 19 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.11it/s]
# ++> Evaluate epoch 19 Finished.
# ==> [2025-04-27_10-25-53] Start Training ablation_trial Epoch 20/100, lr=0.050000 ...
# loss=45223.4180 (15439.5789), lr=0.050000: 100% 100/100 [00:24<00:00,  4.15it/s]
# ==> [2025-04-27_10-26-17] Finished Epoch 20/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 20 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.15it/s]
# ++> Evaluate epoch 20 Finished.
# ==> [2025-04-27_10-26-22] Start Training ablation_trial Epoch 21/100, lr=0.050000 ...
# loss=51396.8281 (14823.8699), lr=0.050000: 100% 100/100 [00:49<00:00,  2.02it/s]
# ==> [2025-04-27_10-27-12] Finished Epoch 21/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 21 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.18it/s]
# ++> Evaluate epoch 21 Finished.
# ==> [2025-04-27_10-27-16] Start Training ablation_trial Epoch 22/100, lr=0.050000 ...
# loss=626.7310 (12735.3374), lr=0.050000: 100% 100/100 [00:48<00:00,  2.05it/s]
# ==> [2025-04-27_10-28-05] Finished Epoch 22/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 22 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.29it/s]
# ++> Evaluate epoch 22 Finished.
# ==> [2025-04-27_10-28-10] Start Training ablation_trial Epoch 23/100, lr=0.050000 ...
# loss=1981.9502 (14913.0264), lr=0.050000: 100% 100/100 [00:48<00:00,  2.04it/s]
# ==> [2025-04-27_10-28-59] Finished Epoch 23/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 23 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.34it/s]
# ++> Evaluate epoch 23 Finished.
# ==> [2025-04-27_10-29-03] Start Training ablation_trial Epoch 24/100, lr=0.050000 ...
# loss=49677.0000 (19242.9710), lr=0.050000: 100% 100/100 [00:48<00:00,  2.05it/s]
# ==> [2025-04-27_10-29-52] Finished Epoch 24/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 24 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.28it/s]
# ++> Evaluate epoch 24 Finished.
# ==> [2025-04-27_10-29-57] Start Training ablation_trial Epoch 25/100, lr=0.050000 ...
# loss=18.0779 (14909.4841), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-30-46] Finished Epoch 25/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 25 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.40it/s]
# ++> Evaluate epoch 25 Finished.
# ==> [2025-04-27_10-30-50] Start Training ablation_trial Epoch 26/100, lr=0.050000 ...
# loss=13347.4238 (16631.7784), lr=0.050000: 100% 100/100 [00:49<00:00,  2.02it/s]
# ==> [2025-04-27_10-31-40] Finished Epoch 26/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 26 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.40it/s]
# ++> Evaluate epoch 26 Finished.
# ==> [2025-04-27_10-31-44] Start Training ablation_trial Epoch 27/100, lr=0.050000 ...
# loss=38498.6211 (16263.5839), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-32-33] Finished Epoch 27/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 27 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.50it/s]
# ++> Evaluate epoch 27 Finished.
# ==> [2025-04-27_10-32-37] Start Training ablation_trial Epoch 28/100, lr=0.050000 ...
# loss=35488.4609 (16245.7056), lr=0.050000: 100% 100/100 [00:48<00:00,  2.07it/s]
# ==> [2025-04-27_10-33-25] Finished Epoch 28/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 28 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.49it/s]
# ++> Evaluate epoch 28 Finished.
# ==> [2025-04-27_10-33-30] Start Training ablation_trial Epoch 29/100, lr=0.050000 ...
# loss=488.7010 (16487.3280), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-34-18] Finished Epoch 29/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 29 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.54it/s]
# ++> Evaluate epoch 29 Finished.
# ==> [2025-04-27_10-34-23] Start Training ablation_trial Epoch 30/100, lr=0.050000 ...
# loss=1488.0127 (17636.6008), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-35-11] Finished Epoch 30/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 30 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.57it/s]
# ++> Evaluate epoch 30 Finished.
# ==> [2025-04-27_10-35-15] Start Training ablation_trial Epoch 31/100, lr=0.050000 ...
# loss=17955.6523 (18997.6662), lr=0.050000: 100% 100/100 [00:48<00:00,  2.05it/s]
# ==> [2025-04-27_10-36-04] Finished Epoch 31/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 31 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.62it/s]
# ++> Evaluate epoch 31 Finished.
# ==> [2025-04-27_10-36-08] Start Training ablation_trial Epoch 32/100, lr=0.050000 ...
# loss=22082.9023 (18550.2647), lr=0.050000: 100% 100/100 [00:49<00:00,  2.02it/s]
# ==> [2025-04-27_10-36-58] Finished Epoch 32/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 32 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.69it/s]
# ++> Evaluate epoch 32 Finished.
# ==> [2025-04-27_10-37-02] Start Training ablation_trial Epoch 33/100, lr=0.050000 ...
# loss=148.1128 (18225.6816), lr=0.050000: 100% 100/100 [00:48<00:00,  2.05it/s]
# ==> [2025-04-27_10-37-51] Finished Epoch 33/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 33 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.74it/s]
# ++> Evaluate epoch 33 Finished.
# ==> [2025-04-27_10-37-55] Start Training ablation_trial Epoch 34/100, lr=0.050000 ...
# loss=24107.3906 (17047.1756), lr=0.050000: 100% 100/100 [00:49<00:00,  2.03it/s]
# ==> [2025-04-27_10-38-44] Finished Epoch 34/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 34 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.57it/s]
# ++> Evaluate epoch 34 Finished.
# ==> [2025-04-27_10-38-51] Start Training ablation_trial Epoch 35/100, lr=0.050000 ...
# loss=54346.3359 (17119.6042), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-39-39] Finished Epoch 35/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 35 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.71it/s]
# ++> Evaluate epoch 35 Finished.
# ==> [2025-04-27_10-39-43] Start Training ablation_trial Epoch 36/100, lr=0.050000 ...
# loss=37907.7656 (20365.2778), lr=0.050000: 100% 100/100 [00:49<00:00,  2.01it/s]
# ==> [2025-04-27_10-40-33] Finished Epoch 36/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 36 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.74it/s]
# ++> Evaluate epoch 36 Finished.
# ==> [2025-04-27_10-40-37] Start Training ablation_trial Epoch 37/100, lr=0.050000 ...
# loss=26660.9375 (17257.7036), lr=0.050000: 100% 100/100 [00:49<00:00,  2.03it/s]
# ==> [2025-04-27_10-41-26] Finished Epoch 37/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 37 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.78it/s]
# ++> Evaluate epoch 37 Finished.
# ==> [2025-04-27_10-41-30] Start Training ablation_trial Epoch 38/100, lr=0.050000 ...
# loss=275.5510 (19709.9108), lr=0.050000: 100% 100/100 [00:48<00:00,  2.08it/s]
# ==> [2025-04-27_10-42-18] Finished Epoch 38/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 38 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.91it/s]
# ++> Evaluate epoch 38 Finished.
# ==> [2025-04-27_10-42-22] Start Training ablation_trial Epoch 39/100, lr=0.050000 ...
# loss=1746.4708 (18011.6008), lr=0.050000: 100% 100/100 [00:49<00:00,  2.04it/s]
# ==> [2025-04-27_10-43-11] Finished Epoch 39/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 39 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.11it/s]
# ++> Evaluate epoch 39 Finished.
# ==> [2025-04-27_10-43-15] Start Training ablation_trial Epoch 40/100, lr=0.050000 ...
# loss=42322.4766 (18306.1472), lr=0.050000: 100% 100/100 [00:48<00:00,  2.04it/s]
# ==> [2025-04-27_10-44-04] Finished Epoch 40/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 40 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.15it/s]
# ++> Evaluate epoch 40 Finished.
# ==> [2025-04-27_10-44-08] Start Training ablation_trial Epoch 41/100, lr=0.050000 ...
# loss=336.5076 (18754.5066), lr=0.050000: 100% 100/100 [00:48<00:00,  2.05it/s]
# ==> [2025-04-27_10-44-57] Finished Epoch 41/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 41 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.05it/s]
# ++> Evaluate epoch 41 Finished.
# ==> [2025-04-27_10-45-00] Start Training ablation_trial Epoch 42/100, lr=0.050000 ...
# loss=39837.0000 (21408.5313), lr=0.050000: 100% 100/100 [00:48<00:00,  2.07it/s]
# ==> [2025-04-27_10-45-49] Finished Epoch 42/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 42 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.29it/s]
# ++> Evaluate epoch 42 Finished.
# ==> [2025-04-27_10-45-52] Start Training ablation_trial Epoch 43/100, lr=0.050000 ...
# loss=30542.0312 (19133.9658), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-46-41] Finished Epoch 43/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 43 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.34it/s]
# ++> Evaluate epoch 43 Finished.
# ==> [2025-04-27_10-46-44] Start Training ablation_trial Epoch 44/100, lr=0.050000 ...
# loss=89.2852 (22628.1463), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-47-33] Finished Epoch 44/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 44 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.31it/s]
# ++> Evaluate epoch 44 Finished.
# ==> [2025-04-27_10-47-37] Start Training ablation_trial Epoch 45/100, lr=0.050000 ...
# loss=25310.4199 (19518.0131), lr=0.050000: 100% 100/100 [00:49<00:00,  2.04it/s]
# ==> [2025-04-27_10-48-26] Finished Epoch 45/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 45 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.21it/s]
# ++> Evaluate epoch 45 Finished.
# ==> [2025-04-27_10-48-29] Start Training ablation_trial Epoch 46/100, lr=0.050000 ...
# loss=29613.3750 (22031.2430), lr=0.050000: 100% 100/100 [00:48<00:00,  2.06it/s]
# ==> [2025-04-27_10-49-18] Finished Epoch 46/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 46 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.43it/s]
# ++> Evaluate epoch 46 Finished.
# ==> [2025-04-27_10-49-21] Start Training ablation_trial Epoch 47/100, lr=0.050000 ...
# loss=23595.2266 (22741.2485), lr=0.050000: 100% 100/100 [00:48<00:00,  2.08it/s]
# ==> [2025-04-27_10-50-09] Finished Epoch 47/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 47 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.79it/s]
# ++> Evaluate epoch 47 Finished.
# ...
# ==> [2025-04-27_11-29-34] Finished Epoch 94/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 94 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  4.91it/s]
# ++> Evaluate epoch 94 Finished.
# ==> [2025-04-27_11-29-37] Start Training ablation_trial Epoch 95/100, lr=0.050000 ...
# loss=17870.7402 (24455.1844), lr=0.050000: 100% 100/100 [00:47<00:00,  2.11it/s]
# ==> [2025-04-27_11-30-24] Finished Epoch 95/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 95 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.16it/s]
# ++> Evaluate epoch 95 Finished.
# ==> [2025-04-27_11-30-27] Start Training ablation_trial Epoch 96/100, lr=0.050000 ...
# loss=47938.5781 (23105.8045), lr=0.050000: 100% 100/100 [00:47<00:00,  2.12it/s]
# ==> [2025-04-27_11-31-14] Finished Epoch 96/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 96 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.39it/s]
# ++> Evaluate epoch 96 Finished.
# ==> [2025-04-27_11-31-17] Start Training ablation_trial Epoch 97/100, lr=0.050000 ...
# loss=7056.4102 (20398.4204), lr=0.050000: 100% 100/100 [00:46<00:00,  2.13it/s]
# ==> [2025-04-27_11-32-04] Finished Epoch 97/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 97 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.39it/s]
# ++> Evaluate epoch 97 Finished.
# ==> [2025-04-27_11-32-06] Start Training ablation_trial Epoch 98/100, lr=0.050000 ...
# loss=7.6781 (26669.7350), lr=0.050000: 100% 100/100 [00:47<00:00,  2.12it/s]
# ==> [2025-04-27_11-32-53] Finished Epoch 98/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 98 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.39it/s]
# ++> Evaluate epoch 98 Finished.
# ==> [2025-04-27_11-32-56] Start Training ablation_trial Epoch 99/100, lr=0.050000 ...
# loss=6189.8076 (21583.2565), lr=0.050000: 100% 100/100 [00:47<00:00,  2.13it/s]
# ==> [2025-04-27_11-33-43] Finished Epoch 99/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 99 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.38it/s]
# ++> Evaluate epoch 99 Finished.
# ==> [2025-04-27_11-33-46] Start Training ablation_trial Epoch 100/100, lr=0.050000 ...
# loss=19920.2344 (24710.9104), lr=0.050000: 100% 100/100 [00:47<00:00,  2.13it/s]
# ==> [2025-04-27_11-34-33] Finished Epoch 100/100. CPU=2.2GB, GPU=8.3GB.
# ++> Evaluate ablation_trial at epoch 100 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.43it/s]
# ++> Evaluate epoch 100 Finished.
# ==> Start Test, save results to ablation_trial/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:16<00:00,  7.11it/s]==> Finished Test.
# 100% 100/100 [00:25<00:00,  3.98it/s]
# [INFO] training takes 81.1281 minutes.
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text=None, negative='', O=True, O2=False, test=True, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py --workspace ablation_trial -O --test
# [INFO] opt: Namespace(file=None, text=None, negative='', O=True, O2=False, test=True,
# six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial', seed=None,
# image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100,
# save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128,
# init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2,
# side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False,
# max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096,
# latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2,
# jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0,
# grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10,
# blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None,
# fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002,
# dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5],
# theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2,
# default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False,
# progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60,
# t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0,
# lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5,
# lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10,
# lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_11-35-20 | cuda | fp16 | ablation_trial
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [INFO] Latest checkpoint is ablation_trial/checkpoints/df_ep0100.pth
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1276: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_dict = torch.load(checkpoint, map_location=self.device)
# [INFO] loaded model.
# [INFO] load at epoch 100, global step 10000
# [WARN] Failed to load optimizer.
# [INFO] loaded scheduler.
# [INFO] loaded scaler.
# ==> Start Test, save results to ablation_trial/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
#   1% 1/100 [00:01<01:50,  1.11s/it]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:16<00:00,  7.12it/s]==> Finished Test.
# 100% 100/100 [00:23<00:00,  4.18it/s]

# %%
## 2. Remove illuminated rendering
# %cd /content/stable-dreamfusion/nerf

import torch
from os import path
import random
from utils import *
from utils import Trainer

# Adjust Trainer.train_step [function]

def train_step_without_textureless_illumination(self, data, save_guidance_path:Path=None):
    """
    Args:
    save_guidance_path: an image that combines the NeRF render, the added latent noise,
    the denoised result and optionally the fully-denoised image.
    """

    # perform RGBD loss instead of SDS if is image-conditioned
    do_rgbd_loss = self.opt.images is not None and \
        (self.global_step % self.opt.known_view_interval == 0)

    # override random camera with fixed known camera
    if do_rgbd_loss:
        data = self.default_view_data

    # experiment iterations ratio
    # i.e. what proportion of this experiment have we completed (in terms of iterations) so far?
    exp_iter_ratio = (self.global_step - self.opt.exp_start_iter) / (self.opt.exp_end_iter - self.opt.exp_start_iter)

    # progressively relaxing view range
    if self.opt.progressive_view:
        r = min(1.0, self.opt.progressive_view_init_ratio + 2.0*exp_iter_ratio)
        self.opt.phi_range = [self.opt.default_azimuth * (1 - r) + self.opt.full_phi_range[0] * r,
                              self.opt.default_azimuth * (1 - r) + self.opt.full_phi_range[1] * r]
        self.opt.theta_range = [self.opt.default_polar * (1 - r) + self.opt.full_theta_range[0] * r,
                                self.opt.default_polar * (1 - r) + self.opt.full_theta_range[1] * r]
        self.opt.radius_range = [self.opt.default_radius * (1 - r) + self.opt.full_radius_range[0] * r,
                                self.opt.default_radius * (1 - r) + self.opt.full_radius_range[1] * r]
        self.opt.fovy_range = [self.opt.default_fovy * (1 - r) + self.opt.full_fovy_range[0] * r,
                                self.opt.default_fovy * (1 - r) + self.opt.full_fovy_range[1] * r]

    # progressively increase max_level
    if self.opt.progressive_level:
        self.model.max_level = min(1.0, 0.25 + 2.0*exp_iter_ratio)

    rays_o = data['rays_o'] # [B, N, 3]
    rays_d = data['rays_d'] # [B, N, 3]
    mvp = data['mvp'] # [B, 4, 4]

    B, N = rays_o.shape[:2]
    H, W = data['H'], data['W']

    # When ref_data has B images > opt.batch_size
    if B > self.opt.batch_size:
        # choose batch_size images out of those B images
        choice = torch.randperm(B)[:self.opt.batch_size]
        B = self.opt.batch_size
        rays_o = rays_o[choice]
        rays_d = rays_d[choice]
        mvp = mvp[choice]

    if do_rgbd_loss:
        ambient_ratio = 1.0
        #An edition for debugging, can be disable if it's unnecessary####################################################################################################
        print("\033[96m[INFO] Enter the do_rgb_loss branch!\033[96m")
        shading = 'lambertian' # use lambertian instead of albedo to get normal
        as_latent = False
        binarize = False
        bg_color = torch.rand((B * N, 3), device=rays_o.device)

        # add camera noise to avoid grid-like artifact
        if self.opt.known_view_noise_scale > 0:
            noise_scale = self.opt.known_view_noise_scale #* (1 - self.global_step / self.opt.iters)
            rays_o = rays_o + torch.randn(3, device=self.device) * noise_scale
            rays_d = rays_d + torch.randn(3, device=self.device) * noise_scale

    elif exp_iter_ratio <= self.opt.latent_iter_ratio:
        ambient_ratio = 1.0
        shading = 'normal'

        #2nd modification: remove illuminated rendering######################################################################################
        shading = 'albedo'
        # as_latent = True
        # binarize = False
        # bg_color = None

    else:
        if exp_iter_ratio <= self.opt.albedo_iter_ratio:
            ambient_ratio = 1.0
            shading = 'albedo'
        else:
            # random shading
            ambient_ratio = self.opt.min_ambient_ratio + (1.0-self.opt.min_ambient_ratio) * random.random()
            rand = random.random()
            if rand >= (1.0 - self.opt.textureless_ratio):
                shading = 'textureless'

                #2nd modification: remove illuminated rendering######################################################################################
                shading = 'albedo'
            else:
                shading = 'lambertian'
                #2nd modification: remove illuminated rendering######################################################################################
                shading = 'albedo'

        as_latent = False

        # random weights binarization (like mobile-nerf) [NOT WORKING NOW]
        # binarize_thresh = min(0.5, -0.5 + self.global_step / self.opt.iters)
        # binarize = random.random() < binarize_thresh
        binarize = False

        # random background
        rand = random.random()
        if self.opt.bg_radius > 0 and rand > 0.5:
            bg_color = None # use bg_net
        else:
            bg_color = torch.rand(3).to(self.device) # single color random bg

    outputs = self.model.render(rays_o, rays_d, mvp, H, W, staged=False, perturb=True, bg_color=bg_color, ambient_ratio=ambient_ratio, shading=shading, binarize=binarize)
    pred_depth = outputs['depth'].reshape(B, 1, H, W)
    pred_mask = outputs['weights_sum'].reshape(B, 1, H, W)
    if 'normal_image' in outputs:
        pred_normal = outputs['normal_image'].reshape(B, H, W, 3)

    if as_latent:
        # abuse normal & mask as latent code for faster geometry initialization (ref: fantasia3D)
        pred_rgb = torch.cat([outputs['image'], outputs['weights_sum'].unsqueeze(-1)], dim=-1).reshape(B, H, W, 4).permute(0, 3, 1, 2).contiguous() # [B, 4, H, W]
    else:
        pred_rgb = outputs['image'].reshape(B, H, W, 3).permute(0, 3, 1, 2).contiguous() # [B, 3, H, W]

    # known view loss
    if do_rgbd_loss:
        gt_mask = self.mask # [B, H, W]
        gt_rgb = self.rgb   # [B, 3, H, W]
        gt_normal = self.normal # [B, H, W, 3]
        gt_depth = self.depth   # [B, H, W]

        if len(gt_rgb) > self.opt.batch_size:
            gt_mask = gt_mask[choice]
            gt_rgb = gt_rgb[choice]
            gt_normal = gt_normal[choice]
            gt_depth = gt_depth[choice]

        # color loss
        gt_rgb = gt_rgb * gt_mask[:, None].float() + bg_color.reshape(B, H, W, 3).permute(0,3,1,2).contiguous() * (1 - gt_mask[:, None].float())
        loss = self.opt.lambda_rgb * F.mse_loss(pred_rgb, gt_rgb)

        # mask loss
        loss = loss + self.opt.lambda_mask * F.mse_loss(pred_mask[:, 0], gt_mask.float())

        # normal loss
        if self.opt.lambda_normal > 0 and 'normal_image' in outputs:
            valid_gt_normal = 1 - 2 * gt_normal[gt_mask] # [B, 3]
            valid_pred_normal = 2 * pred_normal[gt_mask] - 1 # [B, 3]

            lambda_normal = self.opt.lambda_normal * min(1, self.global_step / self.opt.iters)
            loss = loss + lambda_normal * (1 - F.cosine_similarity(valid_pred_normal, valid_gt_normal).mean())

        # relative depth loss
        if self.opt.lambda_depth > 0:
            valid_gt_depth = gt_depth[gt_mask] # [B,]
            valid_pred_depth = pred_depth[:, 0][gt_mask] # [B,]
            lambda_depth = self.opt.lambda_depth * min(1, self.global_step / self.opt.iters)
            loss = loss + lambda_depth * (1 - self.pearson(valid_pred_depth, valid_gt_depth))

            # # scale-invariant
            # with torch.no_grad():
            #     A = torch.cat([valid_gt_depth, torch.ones_like(valid_gt_depth)], dim=-1) # [B, 2]
            #     X = torch.linalg.lstsq(A, valid_pred_depth).solution # [2, 1]
            #     valid_gt_depth = A @ X # [B, 1]
            # lambda_depth = self.opt.lambda_depth #* min(1, self.global_step / self.opt.iters)
            # loss = loss + lambda_depth * F.mse_loss(valid_pred_depth, valid_gt_depth)

    # novel view loss
    else:

        loss = 0

        if 'SD' in self.guidance:
            # interpolate text_z
            azimuth = data['azimuth'] # [-180, 180]

            # ENHANCE: remove loop to handle batch size > 1
            text_z = [self.embeddings['SD']['uncond']] * azimuth.shape[0]
            if self.opt.perpneg:

                text_z_comp, weights = adjust_text_embeddings(self.embeddings['SD'], azimuth, self.opt)
                text_z.append(text_z_comp)

            else:
                for b in range(azimuth.shape[0]):
                    if azimuth[b] >= -90 and azimuth[b] < 90:
                        if azimuth[b] >= 0:
                            r = 1 - azimuth[b] / 90
                        else:
                            r = 1 + azimuth[b] / 90
                        start_z = self.embeddings['SD']['front']
                        end_z = self.embeddings['SD']['side']
                    else:
                        if azimuth[b] >= 0:
                            r = 1 - (azimuth[b] - 90) / 90
                        else:
                            r = 1 + (azimuth[b] + 90) / 90
                        start_z = self.embeddings['SD']['side']
                        end_z = self.embeddings['SD']['back']
                    text_z.append(r * start_z + (1 - r) * end_z)

            text_z = torch.cat(text_z, dim=0)
            if self.opt.perpneg:
                loss = loss + self.guidance['SD'].train_step_perpneg(text_z, weights, pred_rgb, as_latent=as_latent, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance,
                                                save_guidance_path=save_guidance_path)
            else:
                loss = loss + self.guidance['SD'].train_step(text_z, pred_rgb, as_latent=as_latent, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance,
                                                                save_guidance_path=save_guidance_path)

        if 'IF' in self.guidance:
            # interpolate text_z
            azimuth = data['azimuth'] # [-180, 180]

            # ENHANCE: remove loop to handle batch size > 1
            text_z = [self.embeddings['IF']['uncond']] * azimuth.shape[0]
            if self.opt.perpneg:
                text_z_comp, weights = adjust_text_embeddings(self.embeddings['IF'], azimuth, self.opt)
                text_z.append(text_z_comp)
            else:
                for b in range(azimuth.shape[0]):
                    if azimuth[b] >= -90 and azimuth[b] < 90:
                        if azimuth[b] >= 0:
                            r = 1 - azimuth[b] / 90
                        else:
                            r = 1 + azimuth[b] / 90
                        start_z = self.embeddings['IF']['front']
                        end_z = self.embeddings['IF']['side']
                    else:
                        if azimuth[b] >= 0:
                            r = 1 - (azimuth[b] - 90) / 90
                        else:
                            r = 1 + (azimuth[b] + 90) / 90
                        start_z = self.embeddings['IF']['side']
                        end_z = self.embeddings['IF']['back']
                    text_z.append(r * start_z + (1 - r) * end_z)

            text_z = torch.cat(text_z, dim=0)

            if self.opt.perpneg:
                loss = loss + self.guidance['IF'].train_step_perpneg(text_z, weights, pred_rgb, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance)
            else:
                loss = loss + self.guidance['IF'].train_step(text_z, pred_rgb, guidance_scale=self.opt.guidance_scale, grad_scale=self.opt.lambda_guidance)

        if 'zero123' in self.guidance:

            polar = data['polar']
            azimuth = data['azimuth']
            radius = data['radius']

            loss = loss + self.guidance['zero123'].train_step(self.embeddings['zero123']['default'], pred_rgb, polar, azimuth, radius, guidance_scale=self.opt.guidance_scale,
                                                              as_latent=as_latent, grad_scale=self.opt.lambda_guidance, save_guidance_path=save_guidance_path)

        if 'clip' in self.guidance:

            # empirical, far view should apply smaller CLIP loss
            lambda_guidance = 10 * (1 - abs(azimuth) / 180) * self.opt.lambda_guidance

            loss = loss + self.guidance['clip'].train_step(self.embeddings['clip'], pred_rgb, grad_scale=lambda_guidance)

    # regularizations
    if not self.opt.dmtet:

        if self.opt.lambda_opacity > 0:
            loss_opacity = (outputs['weights_sum'] ** 2).mean()
            loss = loss + self.opt.lambda_opacity * loss_opacity

        if self.opt.lambda_entropy > 0:
            alphas = outputs['weights'].clamp(1e-5, 1 - 1e-5)
            # alphas = alphas ** 2 # skewed entropy, favors 0 over 1
            loss_entropy = (- alphas * torch.log2(alphas) - (1 - alphas) * torch.log2(1 - alphas)).mean()
            lambda_entropy = self.opt.lambda_entropy * min(1, 2 * self.global_step / self.opt.iters)
            loss = loss + lambda_entropy * loss_entropy

        if self.opt.lambda_2d_normal_smooth > 0 and 'normal_image' in outputs:
            # pred_vals = outputs['normal_image'].reshape(B, H, W, 3).permute(0, 3, 1, 2).contiguous()
            # smoothed_vals = TF.gaussian_blur(pred_vals.detach(), kernel_size=9)
            # loss_smooth = F.mse_loss(pred_vals, smoothed_vals)
            # total-variation
            loss_smooth = (pred_normal[:, 1:, :, :] - pred_normal[:, :-1, :, :]).square().mean() + \
                          (pred_normal[:, :, 1:, :] - pred_normal[:, :, :-1, :]).square().mean()
            loss = loss + self.opt.lambda_2d_normal_smooth * loss_smooth

        if self.opt.lambda_orient > 0 and 'loss_orient' in outputs:
            loss_orient = outputs['loss_orient']
            loss = loss + self.opt.lambda_orient * loss_orient

        if self.opt.lambda_3d_normal_smooth > 0 and 'loss_normal_perturb' in outputs:
            loss_normal_perturb = outputs['loss_normal_perturb']
            loss = loss + self.opt.lambda_3d_normal_smooth * loss_normal_perturb

    else:

        if self.opt.lambda_mesh_normal > 0:
            loss = loss + self.opt.lambda_mesh_normal * outputs['normal_loss']

        if self.opt.lambda_mesh_laplacian > 0:
            loss = loss + self.opt.lambda_mesh_laplacian * outputs['lap_loss']

    return pred_rgb, pred_depth, loss


# Monkey patching
Trainer.train_step = train_step_without_textureless_illumination
# Out:
# /content/notebooks/stable-dreamfusion/nerf

# %%
# %cd "/content/notebooks/stable-dreamfusion"
# !python main.py -O --text "A bulldog is wearing a black pirate hat." --workspace ablation_trial2
# !python main.py --workspace ablation_trial2 -O --test
# Out:
# /content/notebooks/stable-dreamfusion
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='', O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# 2025-04-27 11:41:25.766424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745754085.984307   54409 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745754086.045818   54409 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 11:41:26.525301: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] loading stable diffusion...
# Loading pipeline components...: 100% 6/6 [00:28<00:00,  4.79s/it]
# [INFO] loaded stable diffusion!
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py -O --text A bulldog is wearing a black pirate hat. --workspace
# ablation_trial2
# [INFO] opt: Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='',
# O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100,
# workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4,
# IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256,
# decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False,
# perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001,
# ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32,
# update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0,
# min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2,
# jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1,
# bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2,
# backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64,
# known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1,
# dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180],
# fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20,
# progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30,
# angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001,
# lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5,
# lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0,
# lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_11-42-01 | cuda | fp16 | ablation_trial2
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [WARN] No checkpoint found, model randomly initialized.
# ==> [2025-04-27_11-42-01] Start Training ablation_trial2 Epoch 1/100, lr=0.050000 ...
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1044: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=40863.1602 (22439.7124), lr=0.050000:  16% 16/100 [00:04<00:17,  4.88it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=11140.9961 (18146.5648), lr=0.050000: 100% 100/100 [00:28<00:00,  3.53it/s]
# ==> [2025-04-27_11-42-29] Finished Epoch 1/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 1 ...
#   0% 0/8 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1141: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.18it/s]
# ++> Evaluate epoch 1 Finished.
# ==> [2025-04-27_11-42-38] Start Training ablation_trial2 Epoch 2/100, lr=0.050000 ...
# loss=20046.0820 (13560.6210), lr=0.050000: 100% 100/100 [00:28<00:00,  3.51it/s]
# ==> [2025-04-27_11-43-06] Finished Epoch 2/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 2 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.16it/s]
# ++> Evaluate epoch 2 Finished.
# ==> [2025-04-27_11-43-15] Start Training ablation_trial2 Epoch 3/100, lr=0.050000 ...
# loss=43421.9141 (12207.6085), lr=0.050000: 100% 100/100 [00:28<00:00,  3.47it/s]
# ==> [2025-04-27_11-43-44] Finished Epoch 3/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 3 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:07<00:00,  1.13it/s]
# ++> Evaluate epoch 3 Finished.
# ==> [2025-04-27_11-43-52] Start Training ablation_trial2 Epoch 4/100, lr=0.050000 ...
# loss=37218.3594 (14358.6908), lr=0.050000: 100% 100/100 [00:29<00:00,  3.37it/s]
# ==> [2025-04-27_11-44-22] Finished Epoch 4/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 4 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:07<00:00,  1.08it/s]
# ++> Evaluate epoch 4 Finished.
# ==> [2025-04-27_11-44-30] Start Training ablation_trial2 Epoch 5/100, lr=0.050000 ...
# loss=40442.7617 (17151.9876), lr=0.050000: 100% 100/100 [00:30<00:00,  3.28it/s]
# ==> [2025-04-27_11-45-01] Finished Epoch 5/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 5 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:08<00:00,  1.12s/it]
# ++> Evaluate epoch 5 Finished.
# ==> [2025-04-27_11-45-11] Start Training ablation_trial2 Epoch 6/100, lr=0.050000 ...
# loss=29651.7773 (20395.3555), lr=0.050000: 100% 100/100 [00:29<00:00,  3.36it/s]
# ==> [2025-04-27_11-45-41] Finished Epoch 6/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 6 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.21it/s]
# ++> Evaluate epoch 6 Finished.
# ==> [2025-04-27_11-45-48] Start Training ablation_trial2 Epoch 7/100, lr=0.050000 ...
# loss=76156.4609 (21902.1767), lr=0.050000: 100% 100/100 [00:27<00:00,  3.69it/s]
# ==> [2025-04-27_11-46-16] Finished Epoch 7/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 7 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.34it/s]
# ++> Evaluate epoch 7 Finished.
# ==> [2025-04-27_11-46-23] Start Training ablation_trial2 Epoch 8/100, lr=0.050000 ...
# loss=18529.7949 (18154.7981), lr=0.050000: 100% 100/100 [00:26<00:00,  3.84it/s]
# ==> [2025-04-27_11-46-49] Finished Epoch 8/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 8 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.55it/s]
# ++> Evaluate epoch 8 Finished.
# ==> [2025-04-27_11-46-55] Start Training ablation_trial2 Epoch 9/100, lr=0.050000 ...
# loss=21669.2031 (20275.1769), lr=0.050000: 100% 100/100 [00:25<00:00,  3.98it/s]
# ==> [2025-04-27_11-47-20] Finished Epoch 9/100. CPU=2.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 9 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.70it/s]
# ++> Evaluate epoch 9 Finished.
# ==> [2025-04-27_11-47-26] Start Training ablation_trial2 Epoch 10/100, lr=0.050000 ...
# loss=36.9895 (18601.9918), lr=0.050000: 100% 100/100 [00:23<00:00,  4.22it/s]
# ==> [2025-04-27_11-47-50] Finished Epoch 10/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 10 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.97it/s]
# ++> Evaluate epoch 10 Finished.
# ==> [2025-04-27_11-47-57] Start Training ablation_trial2 Epoch 11/100, lr=0.050000 ...
# loss=43202.1719 (22868.6872), lr=0.050000: 100% 100/100 [00:23<00:00,  4.34it/s]
# ==> [2025-04-27_11-48-20] Finished Epoch 11/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 11 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.25it/s]
# ++> Evaluate epoch 11 Finished.
# ==> [2025-04-27_11-48-24] Start Training ablation_trial2 Epoch 12/100, lr=0.050000 ...
# loss=26092.6367 (22059.6766), lr=0.050000: 100% 100/100 [00:22<00:00,  4.44it/s]
# ==> [2025-04-27_11-48-47] Finished Epoch 12/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 12 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.39it/s]
# ++> Evaluate epoch 12 Finished.
# ==> [2025-04-27_11-48-52] Start Training ablation_trial2 Epoch 13/100, lr=0.050000 ...
# loss=15804.3848 (23618.8469), lr=0.050000: 100% 100/100 [00:21<00:00,  4.66it/s]
# ==> [2025-04-27_11-49-13] Finished Epoch 13/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 13 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.91it/s]
# ++> Evaluate epoch 13 Finished.
# ==> [2025-04-27_11-49-17] Start Training ablation_trial2 Epoch 14/100, lr=0.050000 ...
# loss=256.4357 (18206.6223), lr=0.050000: 100% 100/100 [00:21<00:00,  4.63it/s]
# ==> [2025-04-27_11-49-39] Finished Epoch 14/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 14 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.06it/s]
# ++> Evaluate epoch 14 Finished.
# ==> [2025-04-27_11-49-42] Start Training ablation_trial2 Epoch 15/100, lr=0.050000 ...
# loss=41903.3828 (27460.2863), lr=0.050000: 100% 100/100 [00:21<00:00,  4.62it/s]
# ==> [2025-04-27_11-50-04] Finished Epoch 15/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 15 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.37it/s]
# ++> Evaluate epoch 15 Finished.
# ==> [2025-04-27_11-50-08] Start Training ablation_trial2 Epoch 16/100, lr=0.050000 ...
# loss=40787.6719 (20592.8599), lr=0.050000: 100% 100/100 [00:21<00:00,  4.73it/s]
# ==> [2025-04-27_11-50-29] Finished Epoch 16/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 16 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.64it/s]
# ++> Evaluate epoch 16 Finished.
# ==> [2025-04-27_11-50-32] Start Training ablation_trial2 Epoch 17/100, lr=0.050000 ...
# loss=19324.4766 (19454.4415), lr=0.050000: 100% 100/100 [00:20<00:00,  4.85it/s]
# ==> [2025-04-27_11-50-53] Finished Epoch 17/100. CPU=2.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 17 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.77it/s]
# ++> Evaluate epoch 17 Finished.
# ==> [2025-04-27_11-50-56] Start Training ablation_trial2 Epoch 18/100, lr=0.050000 ...
# loss=5836.6553 (24544.3689), lr=0.050000: 100% 100/100 [00:20<00:00,  4.84it/s]
# ==> [2025-04-27_11-51-17] Finished Epoch 18/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 18 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  4.83it/s]
# ++> Evaluate epoch 18 Finished.
# ==> [2025-04-27_11-51-21] Start Training ablation_trial2 Epoch 19/100, lr=0.050000 ...
# loss=27440.7109 (22899.5883), lr=0.050000: 100% 100/100 [00:19<00:00,  5.03it/s]
# ==> [2025-04-27_11-51-41] Finished Epoch 19/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 19 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  4.93it/s]
# ++> Evaluate epoch 19 Finished.
# ==> [2025-04-27_11-51-46] Start Training ablation_trial2 Epoch 20/100, lr=0.050000 ...
# loss=24861.5137 (26084.5480), lr=0.050000: 100% 100/100 [00:19<00:00,  5.01it/s]
# ==> [2025-04-27_11-52-06] Finished Epoch 20/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 20 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.32it/s]
# ++> Evaluate epoch 20 Finished.
# ==> [2025-04-27_11-52-10] Start Training ablation_trial2 Epoch 21/100, lr=0.050000 ...
# loss=16342.7227 (17605.2965), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_11-52-55] Finished Epoch 21/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 21 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.86it/s]
# ++> Evaluate epoch 21 Finished.
# ==> [2025-04-27_11-52-58] Start Training ablation_trial2 Epoch 22/100, lr=0.050000 ...
# loss=15214.9092 (15659.1463), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_11-53-43] Finished Epoch 22/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 22 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.74it/s]
# ++> Evaluate epoch 22 Finished.
# ==> [2025-04-27_11-53-45] Start Training ablation_trial2 Epoch 23/100, lr=0.050000 ...
# loss=17032.1289 (17308.6879), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_11-54-30] Finished Epoch 23/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 23 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.90it/s]
# ++> Evaluate epoch 23 Finished.
# ==> [2025-04-27_11-54-33] Start Training ablation_trial2 Epoch 24/100, lr=0.050000 ...
# loss=47445.9805 (17190.9039), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-55-17] Finished Epoch 24/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 24 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.03it/s]
# ++> Evaluate epoch 24 Finished.
# ==> [2025-04-27_11-55-19] Start Training ablation_trial2 Epoch 25/100, lr=0.050000 ...
# loss=19837.2539 (16304.4136), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-56-03] Finished Epoch 25/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 25 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.58it/s]
# ++> Evaluate epoch 25 Finished.
# ==> [2025-04-27_11-56-07] Start Training ablation_trial2 Epoch 26/100, lr=0.050000 ...
# loss=43749.8828 (15591.1836), lr=0.050000: 100% 100/100 [00:44<00:00,  2.25it/s]
# ==> [2025-04-27_11-56-52] Finished Epoch 26/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 26 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  9.14it/s]
# ++> Evaluate epoch 26 Finished.
# ==> [2025-04-27_11-56-54] Start Training ablation_trial2 Epoch 27/100, lr=0.050000 ...
# loss=3238.4023 (15908.5792), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-57-38] Finished Epoch 27/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 27 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  9.49it/s]
# ++> Evaluate epoch 27 Finished.
# ==> [2025-04-27_11-57-40] Start Training ablation_trial2 Epoch 28/100, lr=0.050000 ...
# loss=7.1870 (13827.4376), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-58-24] Finished Epoch 28/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 28 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.49it/s]
# ++> Evaluate epoch 28 Finished.
# ==> [2025-04-27_11-58-28] Start Training ablation_trial2 Epoch 29/100, lr=0.050000 ...
# loss=11602.4512 (16811.6327), lr=0.050000: 100% 100/100 [00:44<00:00,  2.25it/s]
# ==> [2025-04-27_11-59-12] Finished Epoch 29/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 29 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.89it/s]
# ++> Evaluate epoch 29 Finished.
# ==> [2025-04-27_11-59-14] Start Training ablation_trial2 Epoch 30/100, lr=0.050000 ...
# loss=19676.0879 (17376.4920), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-59-58] Finished Epoch 30/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 30 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.02it/s]
# ++> Evaluate epoch 30 Finished.
# ==> [2025-04-27_12-00-00] Start Training ablation_trial2 Epoch 31/100, lr=0.050000 ...
# loss=46359.1172 (17704.2330), lr=0.050000: 100% 100/100 [00:44<00:00,  2.24it/s]
# ==> [2025-04-27_12-00-45] Finished Epoch 31/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 31 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.81it/s]
# ++> Evaluate epoch 31 Finished.
# ==> [2025-04-27_12-00-47] Start Training ablation_trial2 Epoch 32/100, lr=0.050000 ...
# loss=28.4809 (14046.3832), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-01-32] Finished Epoch 32/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 32 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.16it/s]
# ++> Evaluate epoch 32 Finished.
# ==> [2025-04-27_12-01-34] Start Training ablation_trial2 Epoch 33/100, lr=0.050000 ...
# loss=38439.1797 (19021.1701), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-02-19] Finished Epoch 33/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 33 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.98it/s]
# ++> Evaluate epoch 33 Finished.
# ==> [2025-04-27_12-02-21] Start Training ablation_trial2 Epoch 34/100, lr=0.050000 ...
# loss=49247.2812 (16666.3800), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-03-06] Finished Epoch 34/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 34 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.08it/s]
# ++> Evaluate epoch 34 Finished.
# ==> [2025-04-27_12-03-08] Start Training ablation_trial2 Epoch 35/100, lr=0.050000 ...
# loss=610.2829 (17484.0472), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-03-53] Finished Epoch 35/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 35 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.05it/s]
# ++> Evaluate epoch 35 Finished.
# ==> [2025-04-27_12-03-55] Start Training ablation_trial2 Epoch 36/100, lr=0.050000 ...
# loss=151.1406 (17378.7059), lr=0.050000: 100% 100/100 [00:44<00:00,  2.22it/s]
# ==> [2025-04-27_12-04-40] Finished Epoch 36/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 36 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.08it/s]
# ++> Evaluate epoch 36 Finished.
# ==> [2025-04-27_12-04-42] Start Training ablation_trial2 Epoch 37/100, lr=0.050000 ...
# loss=26657.2031 (15899.0393), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-05-27] Finished Epoch 37/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 37 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.12it/s]
# ++> Evaluate epoch 37 Finished.
# ==> [2025-04-27_12-05-29] Start Training ablation_trial2 Epoch 38/100, lr=0.050000 ...
# loss=31400.5684 (16725.7817), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-06-14] Finished Epoch 38/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 38 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.07it/s]
# ++> Evaluate epoch 38 Finished.
# ==> [2025-04-27_12-06-17] Start Training ablation_trial2 Epoch 39/100, lr=0.050000 ...
# loss=35510.4688 (18422.2753), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_12-07-02] Finished Epoch 39/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 39 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.39it/s]
# ++> Evaluate epoch 39 Finished.
# ==> [2025-04-27_12-07-04] Start Training ablation_trial2 Epoch 40/100, lr=0.050000 ...
# loss=17161.8945 (19577.4137), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-07-49] Finished Epoch 40/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 40 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.71it/s]
# ++> Evaluate epoch 40 Finished.
# ==> [2025-04-27_12-07-51] Start Training ablation_trial2 Epoch 41/100, lr=0.050000 ...
# loss=49370.9922 (17472.6069), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-08-37] Finished Epoch 41/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 41 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.05it/s]
# ++> Evaluate epoch 41 Finished.
# ==> [2025-04-27_12-08-39] Start Training ablation_trial2 Epoch 42/100, lr=0.050000 ...
# loss=27176.8105 (19311.8965), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-09-24] Finished Epoch 42/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 42 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.12it/s]
# ++> Evaluate epoch 42 Finished.
# ==> [2025-04-27_12-09-26] Start Training ablation_trial2 Epoch 43/100, lr=0.050000 ...
# loss=1051.6608 (17241.1857), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_12-10-11] Finished Epoch 43/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 43 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.03it/s]
# ++> Evaluate epoch 43 Finished.
# ==> [2025-04-27_12-10-13] Start Training ablation_trial2 Epoch 44/100, lr=0.050000 ...
# loss=10009.3652 (22853.8464), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-10-59] Finished Epoch 44/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 44 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.74it/s]
# ++> Evaluate epoch 44 Finished.
# ==> [2025-04-27_12-11-01] Start Training ablation_trial2 Epoch 45/100, lr=0.050000 ...
# loss=26122.3457 (18175.3789), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-11-46] Finished Epoch 45/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 45 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.68it/s]
# ++> Evaluate epoch 45 Finished.
# ==> [2025-04-27_12-11-48] Start Training ablation_trial2 Epoch 46/100, lr=0.050000 ...
# loss=35364.3867 (16508.1974), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-12-34] Finished Epoch 46/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 46 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.90it/s]
# ++> Evaluate epoch 46 Finished.
# ==> [2025-04-27_12-12-36] Start Training ablation_trial2 Epoch 47/100, lr=0.050000 ...
# loss=1056.4097 (18306.5296), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-13-21] Finished Epoch 47/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 47 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.70it/s]
# ++> Evaluate epoch 47 Finished.
# ==> [2025-04-27_12-13-23] Start Training ablation_trial2 Epoch 48/100, lr=0.050000 ...
# loss=551.0811 (16710.3086), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-14-08] Finished Epoch 48/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 48 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.39it/s]
# ++> Evaluate epoch 48 Finished.
# ==> [2025-04-27_12-14-11] Start Training ablation_trial2 Epoch 49/100, lr=0.050000 ...
# loss=9.2875 (16981.1830), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-14-56] Finished Epoch 49/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 49 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.55it/s]
# ++> Evaluate epoch 49 Finished.
# ==> [2025-04-27_12-14-58] Start Training ablation_trial2 Epoch 50/100, lr=0.050000 ...
# loss=54059.6992 (19175.4135), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-15-44] Finished Epoch 50/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 50 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.97it/s]
# ++> Evaluate epoch 50 Finished.
# ==> [2025-04-27_12-15-46] Start Training ablation_trial2 Epoch 51/100, lr=0.050000 ...
# loss=687.0099 (18109.2560), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-16-32] Finished Epoch 51/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 51 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.73it/s]
# ++> Evaluate epoch 51 Finished.
# ==> [2025-04-27_12-16-34] Start Training ablation_trial2 Epoch 52/100, lr=0.050000 ...
# loss=228.0222 (18507.1251), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-17-19] Finished Epoch 52/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 52 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.07it/s]
# ++> Evaluate epoch 52 Finished.
# ==> [2025-04-27_12-17-24] Start Training ablation_trial2 Epoch 53/100, lr=0.050000 ...
# loss=15668.3652 (18408.6786), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-18-09] Finished Epoch 53/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 53 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.92it/s]
# ++> Evaluate epoch 53 Finished.
# ==> [2025-04-27_12-18-11] Start Training ablation_trial2 Epoch 54/100, lr=0.050000 ...
# loss=8276.4199 (17126.5489), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-18-57] Finished Epoch 54/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 54 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.82it/s]
# ++> Evaluate epoch 54 Finished.
# ==> [2025-04-27_12-18-59] Start Training ablation_trial2 Epoch 55/100, lr=0.050000 ...
# loss=30287.2695 (18122.5403), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-19-44] Finished Epoch 55/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 55 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.16it/s]
# ++> Evaluate epoch 55 Finished.
# ==> [2025-04-27_12-19-47] Start Training ablation_trial2 Epoch 56/100, lr=0.050000 ...
# loss=4025.6802 (18859.9840), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-20-32] Finished Epoch 56/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 56 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.19it/s]
# ++> Evaluate epoch 56 Finished.
# ==> [2025-04-27_12-20-36] Start Training ablation_trial2 Epoch 57/100, lr=0.050000 ...
# loss=264.4242 (20612.6962), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-21-22] Finished Epoch 57/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 57 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.53it/s]
# ++> Evaluate epoch 57 Finished.
# ==> [2025-04-27_12-21-24] Start Training ablation_trial2 Epoch 58/100, lr=0.050000 ...
# loss=24170.8105 (18964.3296), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-22-10] Finished Epoch 58/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 58 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.85it/s]
# ++> Evaluate epoch 58 Finished.
# ==> [2025-04-27_12-22-12] Start Training ablation_trial2 Epoch 59/100, lr=0.050000 ...
# loss=105.7399 (20032.5992), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-22-57] Finished Epoch 59/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 59 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.12it/s]
# ++> Evaluate epoch 59 Finished.
# ==> [2025-04-27_12-23-00] Start Training ablation_trial2 Epoch 60/100, lr=0.050000 ...
# loss=8520.1484 (18625.3317), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-23-45] Finished Epoch 60/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 60 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.25it/s]
# ++> Evaluate epoch 60 Finished.
# ==> [2025-04-27_12-23-47] Start Training ablation_trial2 Epoch 61/100, lr=0.050000 ...
# loss=164.1549 (19877.5182), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-24-32] Finished Epoch 61/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 61 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.28it/s]
# ++> Evaluate epoch 61 Finished.
# ==> [2025-04-27_12-24-34] Start Training ablation_trial2 Epoch 62/100, lr=0.050000 ...
# loss=33085.0391 (16527.1379), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-25-20] Finished Epoch 62/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 62 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.28it/s]
# ++> Evaluate epoch 62 Finished.
# ==> [2025-04-27_12-25-22] Start Training ablation_trial2 Epoch 63/100, lr=0.050000 ...
# loss=7450.7119 (18788.6479), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-26-08] Finished Epoch 63/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 63 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.03it/s]
# ++> Evaluate epoch 63 Finished.
# ==> [2025-04-27_12-26-12] Start Training ablation_trial2 Epoch 64/100, lr=0.050000 ...
# loss=35725.2070 (19071.0290), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-26-58] Finished Epoch 64/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 64 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.60it/s]
# ++> Evaluate epoch 64 Finished.
# ==> [2025-04-27_12-27-00] Start Training ablation_trial2 Epoch 65/100, lr=0.050000 ...
# loss=13919.7344 (15492.0725), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-27-45] Finished Epoch 65/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 65 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.16it/s]
# ++> Evaluate epoch 65 Finished.
# ==> [2025-04-27_12-27-48] Start Training ablation_trial2 Epoch 66/100, lr=0.050000 ...
# loss=39.6504 (16653.4198), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-28-33] Finished Epoch 66/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 66 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.11it/s]
# ++> Evaluate epoch 66 Finished.
# ==> [2025-04-27_12-28-35] Start Training ablation_trial2 Epoch 67/100, lr=0.050000 ...
# loss=11635.7910 (20902.8782), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-29-21] Finished Epoch 67/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 67 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.14it/s]
# ++> Evaluate epoch 67 Finished.
# ==> [2025-04-27_12-29-23] Start Training ablation_trial2 Epoch 68/100, lr=0.050000 ...
# loss=211.5515 (19940.7744), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-30-09] Finished Epoch 68/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 68 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.02it/s]
# ++> Evaluate epoch 68 Finished.
# ==> [2025-04-27_12-30-11] Start Training ablation_trial2 Epoch 69/100, lr=0.050000 ...
# loss=65363.5586 (17851.0440), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-30-56] Finished Epoch 69/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 69 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.01it/s]
# ++> Evaluate epoch 69 Finished.
# ==> [2025-04-27_12-30-58] Start Training ablation_trial2 Epoch 70/100, lr=0.050000 ...
# loss=10524.7744 (18351.2214), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-31-44] Finished Epoch 70/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 70 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.68it/s]
# ++> Evaluate epoch 70 Finished.
# ==> [2025-04-27_12-31-46] Start Training ablation_trial2 Epoch 71/100, lr=0.050000 ...
# loss=15109.3711 (18605.4740), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-32-32] Finished Epoch 71/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 71 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.88it/s]
# ++> Evaluate epoch 71 Finished.
# ==> [2025-04-27_12-32-34] Start Training ablation_trial2 Epoch 72/100, lr=0.050000 ...
# loss=30925.3867 (16292.5746), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-33-19] Finished Epoch 72/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 72 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.00it/s]
# ++> Evaluate epoch 72 Finished.
# ==> [2025-04-27_12-33-22] Start Training ablation_trial2 Epoch 73/100, lr=0.050000 ...
# loss=1345.2307 (18867.6883), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-34-07] Finished Epoch 73/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 73 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.57it/s]
# ++> Evaluate epoch 73 Finished.
# ==> [2025-04-27_12-34-09] Start Training ablation_trial2 Epoch 74/100, lr=0.050000 ...
# loss=30046.2109 (20707.8096), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-34-55] Finished Epoch 74/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 74 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.41it/s]
# ++> Evaluate epoch 74 Finished.
# ==> [2025-04-27_12-34-58] Start Training ablation_trial2 Epoch 75/100, lr=0.050000 ...
# loss=280.6282 (18385.8640), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-35-43] Finished Epoch 75/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 75 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.34it/s]
# ++> Evaluate epoch 75 Finished.
# ==> [2025-04-27_12-35-45] Start Training ablation_trial2 Epoch 76/100, lr=0.050000 ...
# loss=33210.3750 (18890.9233), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-36-31] Finished Epoch 76/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 76 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.52it/s]
# ++> Evaluate epoch 76 Finished.
# ==> [2025-04-27_12-36-35] Start Training ablation_trial2 Epoch 77/100, lr=0.050000 ...
# loss=4360.9658 (19065.3210), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-37-20] Finished Epoch 77/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 77 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.13it/s]
# ++> Evaluate epoch 77 Finished.
# ==> [2025-04-27_12-37-23] Start Training ablation_trial2 Epoch 78/100, lr=0.050000 ...
# loss=27010.6367 (21466.7430), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-38-08] Finished Epoch 78/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 78 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.22it/s]
# ++> Evaluate epoch 78 Finished.
# ==> [2025-04-27_12-38-11] Start Training ablation_trial2 Epoch 79/100, lr=0.050000 ...
# loss=6170.7393 (24180.4362), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-38-56] Finished Epoch 79/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 79 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.29it/s]
# ++> Evaluate epoch 79 Finished.
# ==> [2025-04-27_12-38-59] Start Training ablation_trial2 Epoch 80/100, lr=0.050000 ...
# loss=18213.7734 (20332.5581), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-39-44] Finished Epoch 80/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 80 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.59it/s]
# ++> Evaluate epoch 80 Finished.
# ==> [2025-04-27_12-39-46] Start Training ablation_trial2 Epoch 81/100, lr=0.050000 ...
# loss=57951.3906 (22856.3149), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-40-32] Finished Epoch 81/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 81 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.90it/s]
# ++> Evaluate epoch 81 Finished.
# ==> [2025-04-27_12-40-34] Start Training ablation_trial2 Epoch 82/100, lr=0.050000 ...
# loss=180.5044 (19981.8282), lr=0.050000: 100% 100/100 [00:45<00:00,  2.18it/s]
# ==> [2025-04-27_12-41-20] Finished Epoch 82/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 82 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.77it/s]
# ++> Evaluate epoch 82 Finished.
# ==> [2025-04-27_12-41-24] Start Training ablation_trial2 Epoch 83/100, lr=0.050000 ...
# loss=37949.2344 (18859.6955), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-42-10] Finished Epoch 83/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 83 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.57it/s]
# ++> Evaluate epoch 83 Finished.
# ==> [2025-04-27_12-42-12] Start Training ablation_trial2 Epoch 84/100, lr=0.050000 ...
# loss=152496.1875 (20564.3315), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-42-58] Finished Epoch 84/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 84 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.71it/s]
# ++> Evaluate epoch 84 Finished.
# ==> [2025-04-27_12-43-00] Start Training ablation_trial2 Epoch 85/100, lr=0.050000 ...
# loss=19742.1758 (20374.4753), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-43-46] Finished Epoch 85/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 85 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.65it/s]
# ++> Evaluate epoch 85 Finished.
# ==> [2025-04-27_12-43-48] Start Training ablation_trial2 Epoch 86/100, lr=0.050000 ...
# loss=23997.6250 (25590.3481), lr=0.050000: 100% 100/100 [00:45<00:00,  2.18it/s]
# ==> [2025-04-27_12-44-34] Finished Epoch 86/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 86 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.62it/s]
# ++> Evaluate epoch 86 Finished.
# ==> [2025-04-27_12-44-36] Start Training ablation_trial2 Epoch 87/100, lr=0.050000 ...
# loss=9223.8535 (24338.9243), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-45-22] Finished Epoch 87/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 87 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.34it/s]
# ++> Evaluate epoch 87 Finished.
# ==> [2025-04-27_12-45-26] Start Training ablation_trial2 Epoch 88/100, lr=0.050000 ...
# loss=7228.2861 (25044.3760), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-46-12] Finished Epoch 88/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 88 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.83it/s]
# ++> Evaluate epoch 88 Finished.
# ==> [2025-04-27_12-46-14] Start Training ablation_trial2 Epoch 89/100, lr=0.050000 ...
# loss=21280.9922 (25341.7891), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-46-59] Finished Epoch 89/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 89 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.82it/s]
# ++> Evaluate epoch 89 Finished.
# ==> [2025-04-27_12-47-01] Start Training ablation_trial2 Epoch 90/100, lr=0.050000 ...
# loss=31172.2402 (27586.1113), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-47-47] Finished Epoch 90/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 90 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.64it/s]
# ++> Evaluate epoch 90 Finished.
# ==> [2025-04-27_12-47-49] Start Training ablation_trial2 Epoch 91/100, lr=0.050000 ...
# loss=18.8493 (25035.1950), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-48-35] Finished Epoch 91/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 91 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.59it/s]
# ++> Evaluate epoch 91 Finished.
# ==> [2025-04-27_12-48-37] Start Training ablation_trial2 Epoch 92/100, lr=0.050000 ...
# loss=57438.7539 (22529.6231), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-49-23] Finished Epoch 92/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 92 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.53it/s]
# ++> Evaluate epoch 92 Finished.
# ==> [2025-04-27_12-49-28] Start Training ablation_trial2 Epoch 93/100, lr=0.050000 ...
# loss=796.2245 (23420.2555), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ...
# ++> Evaluate ablation_trial2 at epoch 94 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.71it/s]
# ++> Evaluate epoch 94 Finished.
# ==> [2025-04-27_12-51-05] Start Training ablation_trial2 Epoch 95/100, lr=0.050000 ...
# loss=7569.8311 (19499.7854), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-51-50] Finished Epoch 95/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 95 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.76it/s]
# ++> Evaluate epoch 95 Finished.
# ==> [2025-04-27_12-51-53] Start Training ablation_trial2 Epoch 96/100, lr=0.050000 ...
# loss=10186.3760 (23952.3933), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-52-38] Finished Epoch 96/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 96 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.01it/s]
# ++> Evaluate epoch 96 Finished.
# ==> [2025-04-27_12-52-42] Start Training ablation_trial2 Epoch 97/100, lr=0.050000 ...
# loss=19052.4395 (20275.5345), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-53-28] Finished Epoch 97/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 97 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.75it/s]
# ++> Evaluate epoch 97 Finished.
# ==> [2025-04-27_12-53-30] Start Training ablation_trial2 Epoch 98/100, lr=0.050000 ...
# loss=5961.6597 (23638.1437), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-54-16] Finished Epoch 98/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 98 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.00it/s]
# ++> Evaluate epoch 98 Finished.
# ==> [2025-04-27_12-54-18] Start Training ablation_trial2 Epoch 99/100, lr=0.050000 ...
# loss=38904.7422 (25500.4059), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-55-04] Finished Epoch 99/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 99 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.81it/s]
# ++> Evaluate epoch 99 Finished.
# ==> [2025-04-27_12-55-06] Start Training ablation_trial2 Epoch 100/100, lr=0.050000 ...
# loss=18725.7715 (19129.6080), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-55-51] Finished Epoch 100/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 100 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.77it/s]
# ++> Evaluate epoch 100 Finished.
# ==> Start Test, save results to ablation_trial2/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:13<00:00,  7.82it/s]==> Finished Test.
# 100% 100/100 [00:20<00:00,  4.83it/s]
# [INFO] training takes 74.2194 minutes.
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text=None, negative='', O=True, O2=False, test=True, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py --workspace ablation_trial2 -O --test
# [INFO] opt: Namespace(file=None, text=None, negative='', O=True, O2=False, test=True,
# six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None,
# image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100,
# save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128,
# init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2,
# side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False,
# max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096,
# latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2,
# jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0,
# grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10,
# blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None,
# fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002,
# dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5],
# theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2,
# default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False,
# progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60,
# t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0,
# lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5,
# lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10,
# lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_12-56-25 | cuda | fp16 | ablation_trial2
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [INFO] Latest checkpoint is ablation_trial2/checkpoints/df_ep0100.pth
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1276: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_dict = torch.load(checkpoint, map_location=self.device)
# [INFO] loaded model.
# [INFO] load at epoch 100, global step 10000
# [WARN] Failed to load optimizer.
# [INFO] loaded scheduler.
# [INFO] loaded scaler.
# ==> Start Test, save results to ablation_trial2/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
#   1% 1/100 [00:00<00:56,  1.76it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:13<00:00,  7.96it/s]==> Finished Test.
# 100% 100/100 [00:19<00:00,  5.17it/s]

# %%
# 3. Disable view-dependent text prompts
# %cd /content/notebooks/stable-dreamfusion/nerf

import torch
from os import path
import random
from utils import *
from utils import adjust_text_embeddings

def foo_adjust_text_embeddings(embeddings, azimuth, opt):
    text_z_list = []
    weights_list = []
    K = 0
    for b in range(azimuth.shape[0]):
        # 3rd modification: Disable view-dependent text prompts by fixing the view input to adjust_text_embeddings()#######################################################################################
        # text_z_, weights_ = get_pos_neg_text_embeddings(embeddings, azimuth[b], opt)
        text_z_, weights_ = get_pos_neg_text_embeddings(embeddings, 0, opt)
        K = max(K, weights_.shape[0])
        text_z_list.append(text_z_)
        weights_list.append(weights_)

    # Interleave text_embeddings from different dirs to form a batch
    text_embeddings = []
    for i in range(K):
        for text_z in text_z_list:
            # if uneven length, pad with the first embedding
            text_embeddings.append(text_z[i] if i < len(text_z) else text_z[0])
    text_embeddings = torch.stack(text_embeddings, dim=0) # [B * K, 77, 768]

    # Interleave weights from different dirs to form a batch
    weights = []
    for i in range(K):
        for weights_ in weights_list:
            weights.append(weights_[i] if i < len(weights_) else torch.zeros_like(weights_[0]))
    weights = torch.stack(weights, dim=0) # [B * K]
    return text_embeddings, weights

# Monkey patching
adjust_text_embeddings = foo_adjust_text_embeddings
# Out:
# /content/notebooks/stable-dreamfusion/nerf

# %%
# %cd "/content/notebooks/stable-dreamfusion"
# !python main.py -O --text "A bulldog is wearing a black pirate hat." --workspace ablation_trial3
# !python main.py --workspace ablation_trial3 -O --test
# Out:
# /content/notebooks/stable-dreamfusion
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='', O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# 2025-04-27 11:41:25.766424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745754085.984307   54409 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745754086.045818   54409 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 11:41:26.525301: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] loading stable diffusion...
# Loading pipeline components...: 100% 6/6 [00:28<00:00,  4.79s/it]
# [INFO] loaded stable diffusion!
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py -O --text A bulldog is wearing a black pirate hat. --workspace
# ablation_trial2
# [INFO] opt: Namespace(file=None, text='A bulldog is wearing a black pirate hat.', negative='',
# O=True, O2=False, test=False, six_views=False, eval_interval=1, test_interval=100,
# workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4,
# IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256,
# decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False,
# perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001,
# ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32,
# update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0,
# min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2,
# jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1,
# bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2,
# backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64,
# known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1,
# dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180],
# fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20,
# progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30,
# angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001,
# lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5,
# lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0,
# lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_11-42-01 | cuda | fp16 | ablation_trial2
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [WARN] No checkpoint found, model randomly initialized.
# ==> [2025-04-27_11-42-01] Start Training ablation_trial2 Epoch 1/100, lr=0.050000 ...
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1044: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=40863.1602 (22439.7124), lr=0.050000:  16% 16/100 [00:04<00:17,  4.88it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1036: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=11140.9961 (18146.5648), lr=0.050000: 100% 100/100 [00:28<00:00,  3.53it/s]
# ==> [2025-04-27_11-42-29] Finished Epoch 1/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 1 ...
#   0% 0/8 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:1141: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.18it/s]
# ++> Evaluate epoch 1 Finished.
# ==> [2025-04-27_11-42-38] Start Training ablation_trial2 Epoch 2/100, lr=0.050000 ...
# loss=20046.0820 (13560.6210), lr=0.050000: 100% 100/100 [00:28<00:00,  3.51it/s]
# ==> [2025-04-27_11-43-06] Finished Epoch 2/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 2 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.16it/s]
# ++> Evaluate epoch 2 Finished.
# ==> [2025-04-27_11-43-15] Start Training ablation_trial2 Epoch 3/100, lr=0.050000 ...
# loss=43421.9141 (12207.6085), lr=0.050000: 100% 100/100 [00:28<00:00,  3.47it/s]
# ==> [2025-04-27_11-43-44] Finished Epoch 3/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 3 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:07<00:00,  1.13it/s]
# ++> Evaluate epoch 3 Finished.
# ==> [2025-04-27_11-43-52] Start Training ablation_trial2 Epoch 4/100, lr=0.050000 ...
# loss=37218.3594 (14358.6908), lr=0.050000: 100% 100/100 [00:29<00:00,  3.37it/s]
# ==> [2025-04-27_11-44-22] Finished Epoch 4/100. CPU=3.5GB, GPU=8.9GB.
# ++> Evaluate ablation_trial2 at epoch 4 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:07<00:00,  1.08it/s]
# ++> Evaluate epoch 4 Finished.
# ==> [2025-04-27_11-44-30] Start Training ablation_trial2 Epoch 5/100, lr=0.050000 ...
# loss=40442.7617 (17151.9876), lr=0.050000: 100% 100/100 [00:30<00:00,  3.28it/s]
# ==> [2025-04-27_11-45-01] Finished Epoch 5/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 5 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:08<00:00,  1.12s/it]
# ++> Evaluate epoch 5 Finished.
# ==> [2025-04-27_11-45-11] Start Training ablation_trial2 Epoch 6/100, lr=0.050000 ...
# loss=29651.7773 (20395.3555), lr=0.050000: 100% 100/100 [00:29<00:00,  3.36it/s]
# ==> [2025-04-27_11-45-41] Finished Epoch 6/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 6 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:06<00:00,  1.21it/s]
# ++> Evaluate epoch 6 Finished.
# ==> [2025-04-27_11-45-48] Start Training ablation_trial2 Epoch 7/100, lr=0.050000 ...
# loss=76156.4609 (21902.1767), lr=0.050000: 100% 100/100 [00:27<00:00,  3.69it/s]
# ==> [2025-04-27_11-46-16] Finished Epoch 7/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 7 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.34it/s]
# ++> Evaluate epoch 7 Finished.
# ==> [2025-04-27_11-46-23] Start Training ablation_trial2 Epoch 8/100, lr=0.050000 ...
# loss=18529.7949 (18154.7981), lr=0.050000: 100% 100/100 [00:26<00:00,  3.84it/s]
# ==> [2025-04-27_11-46-49] Finished Epoch 8/100. CPU=3.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 8 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:05<00:00,  1.55it/s]
# ++> Evaluate epoch 8 Finished.
# ==> [2025-04-27_11-46-55] Start Training ablation_trial2 Epoch 9/100, lr=0.050000 ...
# loss=21669.2031 (20275.1769), lr=0.050000: 100% 100/100 [00:25<00:00,  3.98it/s]
# ==> [2025-04-27_11-47-20] Finished Epoch 9/100. CPU=2.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 9 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.70it/s]
# ++> Evaluate epoch 9 Finished.
# ==> [2025-04-27_11-47-26] Start Training ablation_trial2 Epoch 10/100, lr=0.050000 ...
# loss=36.9895 (18601.9918), lr=0.050000: 100% 100/100 [00:23<00:00,  4.22it/s]
# ==> [2025-04-27_11-47-50] Finished Epoch 10/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 10 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:04<00:00,  1.97it/s]
# ++> Evaluate epoch 10 Finished.
# ==> [2025-04-27_11-47-57] Start Training ablation_trial2 Epoch 11/100, lr=0.050000 ...
# loss=43202.1719 (22868.6872), lr=0.050000: 100% 100/100 [00:23<00:00,  4.34it/s]
# ==> [2025-04-27_11-48-20] Finished Epoch 11/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 11 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.25it/s]
# ++> Evaluate epoch 11 Finished.
# ==> [2025-04-27_11-48-24] Start Training ablation_trial2 Epoch 12/100, lr=0.050000 ...
# loss=26092.6367 (22059.6766), lr=0.050000: 100% 100/100 [00:22<00:00,  4.44it/s]
# ==> [2025-04-27_11-48-47] Finished Epoch 12/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 12 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:03<00:00,  2.39it/s]
# ++> Evaluate epoch 12 Finished.
# ==> [2025-04-27_11-48-52] Start Training ablation_trial2 Epoch 13/100, lr=0.050000 ...
# loss=15804.3848 (23618.8469), lr=0.050000: 100% 100/100 [00:21<00:00,  4.66it/s]
# ==> [2025-04-27_11-49-13] Finished Epoch 13/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 13 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  2.91it/s]
# ++> Evaluate epoch 13 Finished.
# ==> [2025-04-27_11-49-17] Start Training ablation_trial2 Epoch 14/100, lr=0.050000 ...
# loss=256.4357 (18206.6223), lr=0.050000: 100% 100/100 [00:21<00:00,  4.63it/s]
# ==> [2025-04-27_11-49-39] Finished Epoch 14/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 14 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.06it/s]
# ++> Evaluate epoch 14 Finished.
# ==> [2025-04-27_11-49-42] Start Training ablation_trial2 Epoch 15/100, lr=0.050000 ...
# loss=41903.3828 (27460.2863), lr=0.050000: 100% 100/100 [00:21<00:00,  4.62it/s]
# ==> [2025-04-27_11-50-04] Finished Epoch 15/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 15 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.37it/s]
# ++> Evaluate epoch 15 Finished.
# ==> [2025-04-27_11-50-08] Start Training ablation_trial2 Epoch 16/100, lr=0.050000 ...
# loss=40787.6719 (20592.8599), lr=0.050000: 100% 100/100 [00:21<00:00,  4.73it/s]
# ==> [2025-04-27_11-50-29] Finished Epoch 16/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 16 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.64it/s]
# ++> Evaluate epoch 16 Finished.
# ==> [2025-04-27_11-50-32] Start Training ablation_trial2 Epoch 17/100, lr=0.050000 ...
# loss=19324.4766 (19454.4415), lr=0.050000: 100% 100/100 [00:20<00:00,  4.85it/s]
# ==> [2025-04-27_11-50-53] Finished Epoch 17/100. CPU=2.5GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 17 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:02<00:00,  3.77it/s]
# ++> Evaluate epoch 17 Finished.
# ==> [2025-04-27_11-50-56] Start Training ablation_trial2 Epoch 18/100, lr=0.050000 ...
# loss=5836.6553 (24544.3689), lr=0.050000: 100% 100/100 [00:20<00:00,  4.84it/s]
# ==> [2025-04-27_11-51-17] Finished Epoch 18/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 18 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  4.83it/s]
# ++> Evaluate epoch 18 Finished.
# ==> [2025-04-27_11-51-21] Start Training ablation_trial2 Epoch 19/100, lr=0.050000 ...
# loss=27440.7109 (22899.5883), lr=0.050000: 100% 100/100 [00:19<00:00,  5.03it/s]
# ==> [2025-04-27_11-51-41] Finished Epoch 19/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 19 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  4.93it/s]
# ++> Evaluate epoch 19 Finished.
# ==> [2025-04-27_11-51-46] Start Training ablation_trial2 Epoch 20/100, lr=0.050000 ...
# loss=24861.5137 (26084.5480), lr=0.050000: 100% 100/100 [00:19<00:00,  5.01it/s]
# ==> [2025-04-27_11-52-06] Finished Epoch 20/100. CPU=2.6GB, GPU=10.0GB.
# ++> Evaluate ablation_trial2 at epoch 20 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.32it/s]
# ++> Evaluate epoch 20 Finished.
# ==> [2025-04-27_11-52-10] Start Training ablation_trial2 Epoch 21/100, lr=0.050000 ...
# loss=16342.7227 (17605.2965), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_11-52-55] Finished Epoch 21/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 21 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.86it/s]
# ++> Evaluate epoch 21 Finished.
# ==> [2025-04-27_11-52-58] Start Training ablation_trial2 Epoch 22/100, lr=0.050000 ...
# loss=15214.9092 (15659.1463), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_11-53-43] Finished Epoch 22/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 22 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.74it/s]
# ++> Evaluate epoch 22 Finished.
# ==> [2025-04-27_11-53-45] Start Training ablation_trial2 Epoch 23/100, lr=0.050000 ...
# loss=17032.1289 (17308.6879), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_11-54-30] Finished Epoch 23/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 23 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.90it/s]
# ++> Evaluate epoch 23 Finished.
# ==> [2025-04-27_11-54-33] Start Training ablation_trial2 Epoch 24/100, lr=0.050000 ...
# loss=47445.9805 (17190.9039), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-55-17] Finished Epoch 24/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 24 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.03it/s]
# ++> Evaluate epoch 24 Finished.
# ==> [2025-04-27_11-55-19] Start Training ablation_trial2 Epoch 25/100, lr=0.050000 ...
# loss=19837.2539 (16304.4136), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-56-03] Finished Epoch 25/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 25 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.58it/s]
# ++> Evaluate epoch 25 Finished.
# ==> [2025-04-27_11-56-07] Start Training ablation_trial2 Epoch 26/100, lr=0.050000 ...
# loss=43749.8828 (15591.1836), lr=0.050000: 100% 100/100 [00:44<00:00,  2.25it/s]
# ==> [2025-04-27_11-56-52] Finished Epoch 26/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 26 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  9.14it/s]
# ++> Evaluate epoch 26 Finished.
# ==> [2025-04-27_11-56-54] Start Training ablation_trial2 Epoch 27/100, lr=0.050000 ...
# loss=3238.4023 (15908.5792), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-57-38] Finished Epoch 27/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 27 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  9.49it/s]
# ++> Evaluate epoch 27 Finished.
# ==> [2025-04-27_11-57-40] Start Training ablation_trial2 Epoch 28/100, lr=0.050000 ...
# loss=7.1870 (13827.4376), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-58-24] Finished Epoch 28/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 28 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.49it/s]
# ++> Evaluate epoch 28 Finished.
# ==> [2025-04-27_11-58-28] Start Training ablation_trial2 Epoch 29/100, lr=0.050000 ...
# loss=11602.4512 (16811.6327), lr=0.050000: 100% 100/100 [00:44<00:00,  2.25it/s]
# ==> [2025-04-27_11-59-12] Finished Epoch 29/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 29 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.89it/s]
# ++> Evaluate epoch 29 Finished.
# ==> [2025-04-27_11-59-14] Start Training ablation_trial2 Epoch 30/100, lr=0.050000 ...
# loss=19676.0879 (17376.4920), lr=0.050000: 100% 100/100 [00:44<00:00,  2.26it/s]
# ==> [2025-04-27_11-59-58] Finished Epoch 30/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 30 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.02it/s]
# ++> Evaluate epoch 30 Finished.
# ==> [2025-04-27_12-00-00] Start Training ablation_trial2 Epoch 31/100, lr=0.050000 ...
# loss=46359.1172 (17704.2330), lr=0.050000: 100% 100/100 [00:44<00:00,  2.24it/s]
# ==> [2025-04-27_12-00-45] Finished Epoch 31/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 31 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.81it/s]
# ++> Evaluate epoch 31 Finished.
# ==> [2025-04-27_12-00-47] Start Training ablation_trial2 Epoch 32/100, lr=0.050000 ...
# loss=28.4809 (14046.3832), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-01-32] Finished Epoch 32/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 32 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.16it/s]
# ++> Evaluate epoch 32 Finished.
# ==> [2025-04-27_12-01-34] Start Training ablation_trial2 Epoch 33/100, lr=0.050000 ...
# loss=38439.1797 (19021.1701), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-02-19] Finished Epoch 33/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 33 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.98it/s]
# ++> Evaluate epoch 33 Finished.
# ==> [2025-04-27_12-02-21] Start Training ablation_trial2 Epoch 34/100, lr=0.050000 ...
# loss=49247.2812 (16666.3800), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-03-06] Finished Epoch 34/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 34 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.08it/s]
# ++> Evaluate epoch 34 Finished.
# ==> [2025-04-27_12-03-08] Start Training ablation_trial2 Epoch 35/100, lr=0.050000 ...
# loss=610.2829 (17484.0472), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-03-53] Finished Epoch 35/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 35 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.05it/s]
# ++> Evaluate epoch 35 Finished.
# ==> [2025-04-27_12-03-55] Start Training ablation_trial2 Epoch 36/100, lr=0.050000 ...
# loss=151.1406 (17378.7059), lr=0.050000: 100% 100/100 [00:44<00:00,  2.22it/s]
# ==> [2025-04-27_12-04-40] Finished Epoch 36/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 36 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.08it/s]
# ++> Evaluate epoch 36 Finished.
# ==> [2025-04-27_12-04-42] Start Training ablation_trial2 Epoch 37/100, lr=0.050000 ...
# loss=26657.2031 (15899.0393), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-05-27] Finished Epoch 37/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 37 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.12it/s]
# ++> Evaluate epoch 37 Finished.
# ==> [2025-04-27_12-05-29] Start Training ablation_trial2 Epoch 38/100, lr=0.050000 ...
# loss=31400.5684 (16725.7817), lr=0.050000: 100% 100/100 [00:44<00:00,  2.23it/s]
# ==> [2025-04-27_12-06-14] Finished Epoch 38/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 38 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.07it/s]
# ++> Evaluate epoch 38 Finished.
# ==> [2025-04-27_12-06-17] Start Training ablation_trial2 Epoch 39/100, lr=0.050000 ...
# loss=35510.4688 (18422.2753), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_12-07-02] Finished Epoch 39/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 39 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.39it/s]
# ++> Evaluate epoch 39 Finished.
# ==> [2025-04-27_12-07-04] Start Training ablation_trial2 Epoch 40/100, lr=0.050000 ...
# loss=17161.8945 (19577.4137), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-07-49] Finished Epoch 40/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 40 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.71it/s]
# ++> Evaluate epoch 40 Finished.
# ==> [2025-04-27_12-07-51] Start Training ablation_trial2 Epoch 41/100, lr=0.050000 ...
# loss=49370.9922 (17472.6069), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-08-37] Finished Epoch 41/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 41 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.05it/s]
# ++> Evaluate epoch 41 Finished.
# ==> [2025-04-27_12-08-39] Start Training ablation_trial2 Epoch 42/100, lr=0.050000 ...
# loss=27176.8105 (19311.8965), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-09-24] Finished Epoch 42/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 42 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.12it/s]
# ++> Evaluate epoch 42 Finished.
# ==> [2025-04-27_12-09-26] Start Training ablation_trial2 Epoch 43/100, lr=0.050000 ...
# loss=1051.6608 (17241.1857), lr=0.050000: 100% 100/100 [00:45<00:00,  2.22it/s]
# ==> [2025-04-27_12-10-11] Finished Epoch 43/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 43 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:00<00:00,  8.03it/s]
# ++> Evaluate epoch 43 Finished.
# ==> [2025-04-27_12-10-13] Start Training ablation_trial2 Epoch 44/100, lr=0.050000 ...
# loss=10009.3652 (22853.8464), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-10-59] Finished Epoch 44/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 44 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.74it/s]
# ++> Evaluate epoch 44 Finished.
# ==> [2025-04-27_12-11-01] Start Training ablation_trial2 Epoch 45/100, lr=0.050000 ...
# loss=26122.3457 (18175.3789), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-11-46] Finished Epoch 45/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 45 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.68it/s]
# ++> Evaluate epoch 45 Finished.
# ==> [2025-04-27_12-11-48] Start Training ablation_trial2 Epoch 46/100, lr=0.050000 ...
# loss=35364.3867 (16508.1974), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-12-34] Finished Epoch 46/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 46 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.90it/s]
# ++> Evaluate epoch 46 Finished.
# ==> [2025-04-27_12-12-36] Start Training ablation_trial2 Epoch 47/100, lr=0.050000 ...
# loss=1056.4097 (18306.5296), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-13-21] Finished Epoch 47/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 47 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.70it/s]
# ++> Evaluate epoch 47 Finished.
# ==> [2025-04-27_12-13-23] Start Training ablation_trial2 Epoch 48/100, lr=0.050000 ...
# loss=551.0811 (16710.3086), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-14-08] Finished Epoch 48/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 48 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.39it/s]
# ++> Evaluate epoch 48 Finished.
# ==> [2025-04-27_12-14-11] Start Training ablation_trial2 Epoch 49/100, lr=0.050000 ...
# loss=9.2875 (16981.1830), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-14-56] Finished Epoch 49/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 49 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.55it/s]
# ++> Evaluate epoch 49 Finished.
# ==> [2025-04-27_12-14-58] Start Training ablation_trial2 Epoch 50/100, lr=0.050000 ...
# loss=54059.6992 (19175.4135), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-15-44] Finished Epoch 50/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 50 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.97it/s]
# ++> Evaluate epoch 50 Finished.
# ==> [2025-04-27_12-15-46] Start Training ablation_trial2 Epoch 51/100, lr=0.050000 ...
# loss=687.0099 (18109.2560), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-16-32] Finished Epoch 51/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 51 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.73it/s]
# ++> Evaluate epoch 51 Finished.
# ==> [2025-04-27_12-16-34] Start Training ablation_trial2 Epoch 52/100, lr=0.050000 ...
# loss=228.0222 (18507.1251), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-17-19] Finished Epoch 52/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 52 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.07it/s]
# ++> Evaluate epoch 52 Finished.
# ==> [2025-04-27_12-17-24] Start Training ablation_trial2 Epoch 53/100, lr=0.050000 ...
# loss=15668.3652 (18408.6786), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-18-09] Finished Epoch 53/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 53 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.92it/s]
# ++> Evaluate epoch 53 Finished.
# ==> [2025-04-27_12-18-11] Start Training ablation_trial2 Epoch 54/100, lr=0.050000 ...
# loss=8276.4199 (17126.5489), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-18-57] Finished Epoch 54/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 54 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.82it/s]
# ++> Evaluate epoch 54 Finished.
# ==> [2025-04-27_12-18-59] Start Training ablation_trial2 Epoch 55/100, lr=0.050000 ...
# loss=30287.2695 (18122.5403), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-19-44] Finished Epoch 55/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 55 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.16it/s]
# ++> Evaluate epoch 55 Finished.
# ==> [2025-04-27_12-19-47] Start Training ablation_trial2 Epoch 56/100, lr=0.050000 ...
# loss=4025.6802 (18859.9840), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-20-32] Finished Epoch 56/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 56 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.19it/s]
# ++> Evaluate epoch 56 Finished.
# ==> [2025-04-27_12-20-36] Start Training ablation_trial2 Epoch 57/100, lr=0.050000 ...
# loss=264.4242 (20612.6962), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-21-22] Finished Epoch 57/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 57 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.53it/s]
# ++> Evaluate epoch 57 Finished.
# ==> [2025-04-27_12-21-24] Start Training ablation_trial2 Epoch 58/100, lr=0.050000 ...
# loss=24170.8105 (18964.3296), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-22-10] Finished Epoch 58/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 58 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.85it/s]
# ++> Evaluate epoch 58 Finished.
# ==> [2025-04-27_12-22-12] Start Training ablation_trial2 Epoch 59/100, lr=0.050000 ...
# loss=105.7399 (20032.5992), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-22-57] Finished Epoch 59/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 59 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.12it/s]
# ++> Evaluate epoch 59 Finished.
# ==> [2025-04-27_12-23-00] Start Training ablation_trial2 Epoch 60/100, lr=0.050000 ...
# loss=8520.1484 (18625.3317), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-23-45] Finished Epoch 60/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 60 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.25it/s]
# ++> Evaluate epoch 60 Finished.
# ==> [2025-04-27_12-23-47] Start Training ablation_trial2 Epoch 61/100, lr=0.050000 ...
# loss=164.1549 (19877.5182), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-24-32] Finished Epoch 61/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 61 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.28it/s]
# ++> Evaluate epoch 61 Finished.
# ==> [2025-04-27_12-24-34] Start Training ablation_trial2 Epoch 62/100, lr=0.050000 ...
# loss=33085.0391 (16527.1379), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-25-20] Finished Epoch 62/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 62 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.28it/s]
# ++> Evaluate epoch 62 Finished.
# ==> [2025-04-27_12-25-22] Start Training ablation_trial2 Epoch 63/100, lr=0.050000 ...
# loss=7450.7119 (18788.6479), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-26-08] Finished Epoch 63/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 63 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.03it/s]
# ++> Evaluate epoch 63 Finished.
# ==> [2025-04-27_12-26-12] Start Training ablation_trial2 Epoch 64/100, lr=0.050000 ...
# loss=35725.2070 (19071.0290), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-26-58] Finished Epoch 64/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 64 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.60it/s]
# ++> Evaluate epoch 64 Finished.
# ==> [2025-04-27_12-27-00] Start Training ablation_trial2 Epoch 65/100, lr=0.050000 ...
# loss=13919.7344 (15492.0725), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-27-45] Finished Epoch 65/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 65 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.16it/s]
# ++> Evaluate epoch 65 Finished.
# ==> [2025-04-27_12-27-48] Start Training ablation_trial2 Epoch 66/100, lr=0.050000 ...
# loss=39.6504 (16653.4198), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-28-33] Finished Epoch 66/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 66 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.11it/s]
# ++> Evaluate epoch 66 Finished.
# ==> [2025-04-27_12-28-35] Start Training ablation_trial2 Epoch 67/100, lr=0.050000 ...
# loss=11635.7910 (20902.8782), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-29-21] Finished Epoch 67/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 67 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.14it/s]
# ++> Evaluate epoch 67 Finished.
# ==> [2025-04-27_12-29-23] Start Training ablation_trial2 Epoch 68/100, lr=0.050000 ...
# loss=211.5515 (19940.7744), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-30-09] Finished Epoch 68/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 68 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.02it/s]
# ++> Evaluate epoch 68 Finished.
# ==> [2025-04-27_12-30-11] Start Training ablation_trial2 Epoch 69/100, lr=0.050000 ...
# loss=65363.5586 (17851.0440), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-30-56] Finished Epoch 69/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 69 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.01it/s]
# ++> Evaluate epoch 69 Finished.
# ==> [2025-04-27_12-30-58] Start Training ablation_trial2 Epoch 70/100, lr=0.050000 ...
# loss=10524.7744 (18351.2214), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-31-44] Finished Epoch 70/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 70 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.68it/s]
# ++> Evaluate epoch 70 Finished.
# ==> [2025-04-27_12-31-46] Start Training ablation_trial2 Epoch 71/100, lr=0.050000 ...
# loss=15109.3711 (18605.4740), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-32-32] Finished Epoch 71/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 71 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.88it/s]
# ++> Evaluate epoch 71 Finished.
# ==> [2025-04-27_12-32-34] Start Training ablation_trial2 Epoch 72/100, lr=0.050000 ...
# loss=30925.3867 (16292.5746), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-33-19] Finished Epoch 72/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 72 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.00it/s]
# ++> Evaluate epoch 72 Finished.
# ==> [2025-04-27_12-33-22] Start Training ablation_trial2 Epoch 73/100, lr=0.050000 ...
# loss=1345.2307 (18867.6883), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-34-07] Finished Epoch 73/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 73 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.57it/s]
# ++> Evaluate epoch 73 Finished.
# ==> [2025-04-27_12-34-09] Start Training ablation_trial2 Epoch 74/100, lr=0.050000 ...
# loss=30046.2109 (20707.8096), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-34-55] Finished Epoch 74/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 74 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.41it/s]
# ++> Evaluate epoch 74 Finished.
# ==> [2025-04-27_12-34-58] Start Training ablation_trial2 Epoch 75/100, lr=0.050000 ...
# loss=280.6282 (18385.8640), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-35-43] Finished Epoch 75/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 75 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.34it/s]
# ++> Evaluate epoch 75 Finished.
# ==> [2025-04-27_12-35-45] Start Training ablation_trial2 Epoch 76/100, lr=0.050000 ...
# loss=33210.3750 (18890.9233), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-36-31] Finished Epoch 76/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 76 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.52it/s]
# ++> Evaluate epoch 76 Finished.
# ==> [2025-04-27_12-36-35] Start Training ablation_trial2 Epoch 77/100, lr=0.050000 ...
# loss=4360.9658 (19065.3210), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-37-20] Finished Epoch 77/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 77 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.13it/s]
# ++> Evaluate epoch 77 Finished.
# ==> [2025-04-27_12-37-23] Start Training ablation_trial2 Epoch 78/100, lr=0.050000 ...
# loss=27010.6367 (21466.7430), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-38-08] Finished Epoch 78/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 78 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.22it/s]
# ++> Evaluate epoch 78 Finished.
# ==> [2025-04-27_12-38-11] Start Training ablation_trial2 Epoch 79/100, lr=0.050000 ...
# loss=6170.7393 (24180.4362), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-38-56] Finished Epoch 79/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 79 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.29it/s]
# ++> Evaluate epoch 79 Finished.
# ==> [2025-04-27_12-38-59] Start Training ablation_trial2 Epoch 80/100, lr=0.050000 ...
# loss=18213.7734 (20332.5581), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-39-44] Finished Epoch 80/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 80 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.59it/s]
# ++> Evaluate epoch 80 Finished.
# ==> [2025-04-27_12-39-46] Start Training ablation_trial2 Epoch 81/100, lr=0.050000 ...
# loss=57951.3906 (22856.3149), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-40-32] Finished Epoch 81/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 81 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.90it/s]
# ++> Evaluate epoch 81 Finished.
# ==> [2025-04-27_12-40-34] Start Training ablation_trial2 Epoch 82/100, lr=0.050000 ...
# loss=180.5044 (19981.8282), lr=0.050000: 100% 100/100 [00:45<00:00,  2.18it/s]
# ==> [2025-04-27_12-41-20] Finished Epoch 82/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 82 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  5.77it/s]
# ++> Evaluate epoch 82 Finished.
# ==> [2025-04-27_12-41-24] Start Training ablation_trial2 Epoch 83/100, lr=0.050000 ...
# loss=37949.2344 (18859.6955), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-42-10] Finished Epoch 83/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 83 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.57it/s]
# ++> Evaluate epoch 83 Finished.
# ==> [2025-04-27_12-42-12] Start Training ablation_trial2 Epoch 84/100, lr=0.050000 ...
# loss=152496.1875 (20564.3315), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-42-58] Finished Epoch 84/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 84 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.71it/s]
# ++> Evaluate epoch 84 Finished.
# ==> [2025-04-27_12-43-00] Start Training ablation_trial2 Epoch 85/100, lr=0.050000 ...
# loss=19742.1758 (20374.4753), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-43-46] Finished Epoch 85/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 85 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.65it/s]
# ++> Evaluate epoch 85 Finished.
# ==> [2025-04-27_12-43-48] Start Training ablation_trial2 Epoch 86/100, lr=0.050000 ...
# loss=23997.6250 (25590.3481), lr=0.050000: 100% 100/100 [00:45<00:00,  2.18it/s]
# ==> [2025-04-27_12-44-34] Finished Epoch 86/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 86 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.62it/s]
# ++> Evaluate epoch 86 Finished.
# ==> [2025-04-27_12-44-36] Start Training ablation_trial2 Epoch 87/100, lr=0.050000 ...
# loss=9223.8535 (24338.9243), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-45-22] Finished Epoch 87/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 87 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.34it/s]
# ++> Evaluate epoch 87 Finished.
# ==> [2025-04-27_12-45-26] Start Training ablation_trial2 Epoch 88/100, lr=0.050000 ...
# loss=7228.2861 (25044.3760), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-46-12] Finished Epoch 88/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 88 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.83it/s]
# ++> Evaluate epoch 88 Finished.
# ==> [2025-04-27_12-46-14] Start Training ablation_trial2 Epoch 89/100, lr=0.050000 ...
# loss=21280.9922 (25341.7891), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-46-59] Finished Epoch 89/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 89 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.82it/s]
# ++> Evaluate epoch 89 Finished.
# ==> [2025-04-27_12-47-01] Start Training ablation_trial2 Epoch 90/100, lr=0.050000 ...
# loss=31172.2402 (27586.1113), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-47-47] Finished Epoch 90/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 90 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.64it/s]
# ++> Evaluate epoch 90 Finished.
# ==> [2025-04-27_12-47-49] Start Training ablation_trial2 Epoch 91/100, lr=0.050000 ...
# loss=18.8493 (25035.1950), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-48-35] Finished Epoch 91/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 91 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.59it/s]
# ++> Evaluate epoch 91 Finished.
# ==> [2025-04-27_12-48-37] Start Training ablation_trial2 Epoch 92/100, lr=0.050000 ...
# loss=57438.7539 (22529.6231), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-49-23] Finished Epoch 92/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 92 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.53it/s]
# ++> Evaluate epoch 92 Finished.
# ==> [2025-04-27_12-49-28] Start Training ablation_trial2 Epoch 93/100, lr=0.050000 ...
# loss=796.2245 (23420.2555), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ...
# ++> Evaluate ablation_trial2 at epoch 94 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.71it/s]
# ++> Evaluate epoch 94 Finished.
# ==> [2025-04-27_12-51-05] Start Training ablation_trial2 Epoch 95/100, lr=0.050000 ...
# loss=7569.8311 (19499.7854), lr=0.050000: 100% 100/100 [00:45<00:00,  2.20it/s]
# ==> [2025-04-27_12-51-50] Finished Epoch 95/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 95 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.76it/s]
# ++> Evaluate epoch 95 Finished.
# ==> [2025-04-27_12-51-53] Start Training ablation_trial2 Epoch 96/100, lr=0.050000 ...
# loss=10186.3760 (23952.3933), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-52-38] Finished Epoch 96/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 96 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.01it/s]
# ++> Evaluate epoch 96 Finished.
# ==> [2025-04-27_12-52-42] Start Training ablation_trial2 Epoch 97/100, lr=0.050000 ...
# loss=19052.4395 (20275.5345), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-53-28] Finished Epoch 97/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 97 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.75it/s]
# ++> Evaluate epoch 97 Finished.
# ==> [2025-04-27_12-53-30] Start Training ablation_trial2 Epoch 98/100, lr=0.050000 ...
# loss=5961.6597 (23638.1437), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-54-16] Finished Epoch 98/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 98 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  7.00it/s]
# ++> Evaluate epoch 98 Finished.
# ==> [2025-04-27_12-54-18] Start Training ablation_trial2 Epoch 99/100, lr=0.050000 ...
# loss=38904.7422 (25500.4059), lr=0.050000: 100% 100/100 [00:45<00:00,  2.19it/s]
# ==> [2025-04-27_12-55-04] Finished Epoch 99/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 99 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.81it/s]
# ++> Evaluate epoch 99 Finished.
# ==> [2025-04-27_12-55-06] Start Training ablation_trial2 Epoch 100/100, lr=0.050000 ...
# loss=18725.7715 (19129.6080), lr=0.050000: 100% 100/100 [00:45<00:00,  2.21it/s]
# ==> [2025-04-27_12-55-51] Finished Epoch 100/100. CPU=2.6GB, GPU=10.5GB.
# ++> Evaluate ablation_trial2 at epoch 100 ...
# loss=0.0000 (0.0000): 100% 8/8 [00:01<00:00,  6.77it/s]
# ++> Evaluate epoch 100 Finished.
# ==> Start Test, save results to ablation_trial2/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:13<00:00,  7.82it/s]==> Finished Test.
# 100% 100/100 [00:20<00:00,  4.83it/s]
# [INFO] training takes 74.2194 minutes.
# /content/notebooks/stable-dreamfusion/nerf/utils.py:112: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/activation.py:7: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float)
# /content/notebooks/stable-dreamfusion/activation.py:13: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:33: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:66: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:143: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:199: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:263: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:298: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:325: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /content/notebooks/stable-dreamfusion/raymarching/raymarching.py:376: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # need to cast sigmas & rgbs to float
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:208: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/nerf/renderer.py:247: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Namespace(file=None, text=None, negative='', O=True, O2=False, test=True, six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:27: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:74: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:172: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /content/notebooks/stable-dreamfusion/gridencoder/grid.py:195: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:17: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32) # force float32 for better precision
# /content/notebooks/stable-dreamfusion/freqencoder/freq.py:38: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# NeRFNetwork(
#   (encoder): GridEncoder: input_dim=3 num_levels=16 level_dim=2 resolution=16 -> 2048 per_level_scale=1.3819 params=(6098120, 2) gridtype=hash align_corners=False interpolation=smoothstep
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): Linear(in_features=39, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# /content/notebooks/stable-dreamfusion/nerf/utils.py:287: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.fp16)
# [INFO] Cmdline: main.py --workspace ablation_trial2 -O --test
# [INFO] opt: Namespace(file=None, text=None, negative='', O=True, O2=False, test=True,
# six_views=False, eval_interval=1, test_interval=100, workspace='ablation_trial2', seed=None,
# image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100,
# save_mesh=False, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128,
# init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2,
# side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=True, taichi_ray=False,
# max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096,
# latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2,
# jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0,
# grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10,
# blob_density=5, blob_radius=0.2, backbone='grid', optim='adan', sd_version='2.1', hf_key=None,
# fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002,
# dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5],
# theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2,
# default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False,
# progressive_view_init_ratio=0.2, progressive_level=False, angle_overhead=30, angle_front=60,
# t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.001, lambda_opacity=0,
# lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5,
# lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10,
# lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False,
# save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0,
# max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml',
# zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle',
# dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0,
# exp_end_iter=10000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[],
# default_zero123_w=1)
# [INFO] Trainer: df | 2025-04-27_12-56-25 | cuda | fp16 | ablation_trial2
# [INFO] #parameters: 12204151
# [INFO] Loading latest checkpoint ...
# [INFO] Latest checkpoint is ablation_trial2/checkpoints/df_ep0100.pth
# /content/notebooks/stable-dreamfusion/nerf/utils.py:1276: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_dict = torch.load(checkpoint, map_location=self.device)
# [INFO] loaded model.
# [INFO] load at epoch 100, global step 10000
# [WARN] Failed to load optimizer.
# [INFO] loaded scheduler.
# [INFO] loaded scaler.
# ==> Start Test, save results to ablation_trial2/results
#   0% 0/100 [00:00<?, ?it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
#   1% 1/100 [00:00<00:56,  1.76it/s]/content/notebooks/stable-dreamfusion/nerf/utils.py:861: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.fp16):
# 100% 100/100 [00:13<00:00,  7.96it/s]==> Finished Test.
# 100% 100/100 [00:19<00:00,  5.17it/s]
